# %% [markdown]
# #### <b>Compiled by Kevin Mugo Mwaniki</b>
# #### <b>Contact: +254726279800</b>
# #### <b>Email: kevmwaniki254@gmail.com</b>
#
#
# # <u>Chapter 6: Index Alignment</u>
# ## <u>Recipes</u>
# * [Examining the Index object](#Examining-the-index)
# * [Producing Cartesian products](#Producing-Cartesian-products)
# * [Exploding indexes](#Exploding-Indexes)
# * [Filling values with unequal indexes](#Filling-values-with-unequal-indexes)
# * [Appending columns from different DataFrames](#Appending-columns-from-different-DataFrames)
# * [Highlighting the maximum value from each column](#Highlighting-maximum-value-from-each-column)
# * [Replicating idxmax with method chaining](#Replicating-idxmax-with-method-chaining)
# * [Finding the most common maximum](#Finding-the-most-common-maximum)
#
# ## <u>Introduction</u>
# <p>When multiple Series or DataFrames are combined in some way, each dimension of the data automatically aligns on each axis
# first before any computation happens. This silent and automatic alignment of axes can cause tremendous confusion for the
# uninitiated, but it gives great flexibility to the power user. This chapter explores the Index object in-depth before
# showcasing a variety of recipes that take advantage of its automatic alignment</p>
#
# ## <u>Examining the Index object</u>
# <p>Each axis of Series and DataFrames has an Index object that labels the values. There are many different types of Index objects, but they all share the same common behavior. All Index objects, except for the special MultiIndex, are single-dimensional data structures that combine the functionality and implementation of Python sets and NumPy ndarrays.</p>

# %%
import pandas as pd
import numpy as np
#We will explore the index of the column dataset to understand its functionality
college = pd.read_csv('data/college.csv')

# %%
#Assign the index to a variable then output it:
columns = college.columns
columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
# 4    0.0243     0.0137    0.0892         1   0.7347    0.7554   0.1270
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
# 2            40100               23370
# 3            45500               24097
# 4            26600             33118.5
#
# [5 rows x 27 columns]

# %%
#Use the values attribute to access the underlying NumPy array:
columns.values
# Out:
# array(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY',
#        'RELAFFIL', 'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS',
#        'UGDS_WHITE', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN',
#        'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF',
#        'CURROPER', 'PCTPELL', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10',
#        'GRAD_DEBT_MDN_SUPP'], dtype=object)

# %%
type(columns)
#loc and iloc
# Out:
# pandas.core.indexes.base.Index

# %%
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
# 4    0.0243     0.0137    0.0892         1   0.7347    0.7554   0.1270
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
# 2            40100               23370
# 3            45500               24097
# 4            26600             33118.5
#
# [5 rows x 27 columns]

# %%
columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
#Select items from the index by integer location with scalars, lists, or slices:
columns[5]
# Out:
# 'WOMENONLY'

# %%
columns[[1, 8, 10]]
# Out:
# Index(['CITY', 'SATMTMID', 'UGDS'], dtype='object')

# %%
college.dtypes
# Out:
# INSTNM                 object
# CITY                   object
# STABBR                 object
# HBCU                  float64
# MENONLY               float64
# WOMENONLY             float64
# RELAFFIL                int64
# SATVRMID              float64
# SATMTMID              float64
# DISTANCEONLY          float64
# UGDS                  float64
# UGDS_WHITE            float64
# UGDS_BLACK            float64
# UGDS_HISP             float64
# UGDS_ASIAN            float64
# UGDS_AIAN             float64
# UGDS_NHPI             float64
# UGDS_2MOR             float64
# UGDS_NRA              float64
# UGDS_UNKN             float64
# PPTUG_EF              float64
# CURROPER                int64
# PCTPELL               float64
# PCTFLOAN              float64
# UG25ABV               float64
# MD_EARN_WNE_P10        object
# GRAD_DEBT_MDN_SUPP     object
# dtype: object

# %%
#Other methods that can be implemented on indexes:
columns.min(),columns.max(), columns.isnull().sum()
# Out:
# ('CITY', 'WOMENONLY', 0)

# %%
columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
#Basic arithmetic and comparison on Index objects:
columns + '_A'
# Out:
# Index(['INSTNM_A', 'CITY_A', 'STABBR_A', 'HBCU_A', 'MENONLY_A', 'WOMENONLY_A',
#        'RELAFFIL_A', 'SATVRMID_A', 'SATMTMID_A', 'DISTANCEONLY_A', 'UGDS_A',
#        'UGDS_WHITE_A', 'UGDS_BLACK_A', 'UGDS_HISP_A', 'UGDS_ASIAN_A',
#        'UGDS_AIAN_A', 'UGDS_NHPI_A', 'UGDS_2MOR_A', 'UGDS_NRA_A',
#        'UGDS_UNKN_A', 'PPTUG_EF_A', 'CURROPER_A', 'PCTPELL_A', 'PCTFLOAN_A',
#        'UG25ABV_A', 'MD_EARN_WNE_P10_A', 'GRAD_DEBT_MDN_SUPP_A'],
#       dtype='object')

# %%
#Indexes are immutable thus changing values after creation will fail:
#columns[1] = 'city'

# %%
l = [66, 65, 64]
t = (66, 65, 64)

# %%
type(l)
# Out:
# list

# %%
columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
#They support set operations, union, intersection, differences and symmetric:
c1 = columns[:4]
c1
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU'], dtype='object')

# %%
l1 = [66, 65, 64]
l2 = [66, 65, 67]

#Union
union = [66, 65, 64, 66, 65, 67]

#Intersection
intersection = [66, 65]

#Difference
difference = [64, 67]

# %%
c2 = columns[2 : 6]
c2
# Out:
# Index(['STABBR', 'HBCU', 'MENONLY', 'WOMENONLY'], dtype='object')

# %%
c1.union(c2) #Alternative of c1 | c2
# Out:
# Index(['CITY', 'HBCU', 'INSTNM', 'MENONLY', 'STABBR', 'WOMENONLY'], dtype='object')

# %%
c1.symmetric_difference(c2) #Alternative of c1 ^ c2
# Out:
# Index(['CITY', 'INSTNM', 'MENONLY', 'WOMENONLY'], dtype='object')

# %%
c1
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU'], dtype='object')

# %%
c2
# Out:
# Index(['STABBR', 'HBCU', 'MENONLY', 'WOMENONLY'], dtype='object')

# %% [markdown]
# <p>Indexes share some of the same operations as Python sets. Indexes are similar to Python sets in another important way. They
# are (usually) implemented using hash tables, which makefor extremely fast access when selecting rows or columns from a
# DataFrame. As they are implemented using hash tables, the values for the Index object need to be immutable such as a string,
# integer, or tuple just like the keys in a Python dictionary.Indexes support duplicate values, and if there happens to be a
# duplicate in any Index, then a hash table can no longer be used for its implementation, and object access becomes much slower.
# </p>
#
# ## <u>Producing Cartesian products</u>
# <p>The first process that occurs when two or more Series or DataFrames operate with one another is the indexes(for both row
# and columns) align before any task is carried out on them. A cartesian product is silently created between the data unless
# they are identical. Here, we will demonstrate two Series overlapping but non-identical indexes are added together thus a
# surprising result</p>

# %%
s1 = pd.Series(index = list('aaab'), data = np.arange(4))
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# dtype: int32

# %%
s2 = pd.Series(index = list('cababb'), data = np.arange(6))
s2
# Out:
# c    0
# a    1
# b    2
# a    3
# b    4
# b    5
# dtype: int32

# %%
#Add the two Series together to form a cartesian product:
s1 + s2
# Out:
# a    1.0
# a    3.0
# a    2.0
# a    4.0
# a    3.0
# a    5.0
# b    5.0
# b    7.0
# b    8.0
# c    NaN
# dtype: float64

# %%
#When the Series have the same indexes and elements, a cartesian product does not occur:
s1 = pd.Series(index = list('aaabb'), data = np.arange(5))
s2 = pd.Series(index = list('aaabb'), data = np.arange(5))

# %%
s1 + s2
# Out:
# a    0
# a    2
# a    4
# b    6
# b    8
# dtype: int32

# %%
#When the indexes are different but the data is the same, a cartesian product occurs:
s1 = pd.Series(index = list('aaabb'), data = np.arange(5))
s2 = pd.Series(index = list('bbaaa'), data = np.arange(5))

# %%
s1 + s2
# Out:
# a    2
# a    3
# a    4
# a    3
# a    4
# a    5
# a    4
# a    5
# a    6
# b    3
# b    4
# b    4
# b    5
# dtype: int32

# %% [markdown]
# ## <u>Exploding indexes</u>
# <p>The above processes can produce commically different results when dealing with larger data. Here, we will add up two Series
# with similar indexes with few unique values but in different orders. The result will explode the number of values in the
# indexes</p>

# %%
#Read in the employee data and set the index equal to the race column:
employee = pd.read_csv('data/employee.csv', index_col = 'RACE')

# %%
employee.head()
# Out:
#                  UNIQUE_ID               POSITION_TITLE  \
# RACE
# Hispanic/Latino          0  ASSISTANT DIRECTOR (EX LVL)
# Hispanic/Latino          1            LIBRARY ASSISTANT
# White                    2               POLICE OFFICER
# White                    3            ENGINEER/OPERATOR
# White                    4                  ELECTRICIAN
#
#                                     DEPARTMENT  BASE_SALARY EMPLOYMENT_TYPE  \
# RACE
# Hispanic/Latino    Municipal Courts Department     121862.0       Full Time
# Hispanic/Latino                        Library      26125.0       Full Time
# White            Houston Police Department-HPD      45279.0       Full Time
# White            Houston Fire Department (HFD)      63166.0       Full Time
# White              General Services Department      56347.0       Full Time
#
#                  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# RACE
# Hispanic/Latino  Female            Active  2006-06-12  2012-10-13
# Hispanic/Latino  Female            Active  2000-07-19  2010-09-18
# White              Male            Active  2015-02-03  2015-02-03
# White              Male            Active  1982-02-08  1991-05-25
# White              Male            Active  1989-06-19  1994-10-22

# %%
#Select the BASE_SALARY as two different Series and check whether they are equal
salary1 = employee['BASE_SALARY']
salary2 = employee['BASE_SALARY']

# %%
salary1
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
#                                       ...
# NaN                                  40000.0
# NaN                                  28024.0
# NaN                                  28766.0
# NaN                                      NaN
# NaN                                  28024.0
# Name: BASE_SALARY, Length: 2000, dtype: float64

# %%
salary2
# Out:
# RACE
# Hispanic/Latino              121862.0
# Hispanic/Latino               26125.0
# White                         45279.0
# White                         63166.0
# White                         56347.0
#                                ...
# White                         43443.0
# Black or African American     66523.0
# White                         43443.0
# Asian/Pacific Islander        55461.0
# Hispanic/Latino               51194.0
# Name: BASE_SALARY, Length: 2000, dtype: float64

# %%
salary1 is salary2
# Out:
# True

# %%
#Any change to one Series will affect the other
#To ensure you receive a brand new copy of the data, use the copy method:
#This will enable the Series to be referenced differently
salary1 = employee.BASE_SALARY.copy()
salary1 = employee.BASE_SALARY.copy()
salary1 is salary2
# Out:
# False

# %%
#Let us change the order of the index by sorting it:
salary1 = salary1.sort_index()

# %%
salary1.index.value_counts()
# Out:
# Black or African American            700
# White                                665
# Hispanic/Latino                      480
# Asian/Pacific Islander               107
# American Indian or Alaskan Native     11
# Others                                 2
# Name: RACE, dtype: int64

# %%
employee.RACE.value_counts()
# Out:
# Black or African American            700
# White                                665
# Hispanic/Latino                      480
# Asian/Pacific Islander               107
# American Indian or Alaskan Native     11
# Others                                 2
# Name: RACE, dtype: int64

# %%
salary1.head()
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
# Name: BASE_SALARY, dtype: float64

# %%
salary2.head()
# Out:
# RACE
# Hispanic/Latino    121862.0
# Hispanic/Latino     26125.0
# White               45279.0
# White               63166.0
# White               56347.0
# Name: BASE_SALARY, dtype: float64

# %%
salary1.head()
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    26125.0
# American Indian or Alaskan Native    98536.0
# American Indian or Alaskan Native        NaN
# American Indian or Alaskan Native    55461.0
# Name: BASE_SALARY, dtype: float64

# %%
salary2.head()
# Out:
# RACE
# Hispanic/Latino    121862.0
# Hispanic/Latino     26125.0
# White               45279.0
# White               63166.0
# White               56347.0
# Name: BASE_SALARY, dtype: float64

# %%
salary1.index[0:6]
# Out:
# Index(['American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native',
#        'American Indian or Alaskan Native'],
#       dtype='object', name='RACE')

# %%
salary2.index[0:6]
# Out:
# Index(['Hispanic/Latino', 'Hispanic/Latino', 'White', 'White', 'White',
#        'Black or African American'],
#       dtype='object', name='RACE')

# %%
#Let us add the Series salary together:
salary_add = salary1 + salary2
salary_add.head()
# Out:
# RACE
# American Indian or Alaskan Native    138702.0
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native    176891.0
# American Indian or Alaskan Native    159594.0
# American Indian or Alaskan Native    127734.0
# Name: BASE_SALARY, dtype: float64

# %%
salary_add.shape
# Out:
# (1175424,)

# %%
salary1.shape
# Out:
# (2000,)

# %%
salary2.shape
# Out:
# (2000,)

# %%
#The following will make the Series to explode from 2000 to over 1 million:
salary_add1 = salary1 + salary1
len(salary1), len(salary2), len(salary_add), len(salary_add1)
# Out:
# (2000, 2000, 1175424, 2000)

# %%
#We can sum the square of the indexes individual counts. 
#Even missing values in the index produce Cartesian products with themselves:
index_vc = salary1.index.value_counts(dropna = False)
index_vc
# Out:
# Black or African American            700
# White                                665
# Hispanic/Latino                      480
# Asian/Pacific Islander               107
# NaN                                   35
# American Indian or Alaskan Native     11
# Others                                 2
# Name: RACE, dtype: int64

# %%
index_vc.pow(2).sum()
# Out:
# 1175424

# %% [markdown]
# ## <u>Filling values with unequal indexes</u>
# <p>When two Series are added together(with one of the index labels is absent in the other), this will result in the formation
# of a missing value. The add method is used to solve this problem. Here, we will add different values from the baseball dataset
# with unequal indexes using the fill_value parameter of the add method to ensure that there are no missing values in the output
# </p>

# %%
baseball_14 = pd.read_csv('data/baseball14.csv', index_col='playerID')
baseball_15 = pd.read_csv('data/baseball15.csv', index_col='playerID')
baseball_16 = pd.read_csv('data/baseball16.csv', index_col='playerID')

# %%
baseball_14.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...   RBI  \
# playerID                                                         ...
# altuvjo01    2014      1    HOU   AL  158  660  85  225  47   3  ...  59.0
# cartech02    2014      1    HOU   AL  145  507  68  115  21   1  ...  88.0
# castrja01    2014      1    HOU   AL  126  465  43  103  21   2  ...  56.0
# corpoca01    2014      1    HOU   AL   55  170  22   40   6   0  ...  19.0
# dominma01    2014      1    HOU   AL  157  564  51  121  17   0  ...  57.0
#
#              SB   CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  56.0  9.0  36   53.0  7.0  5.0  1.0  5.0  20.0
# cartech02   5.0  2.0  56  182.0  6.0  5.0  0.0  4.0  12.0
# castrja01   1.0  0.0  34  151.0  1.0  9.0  1.0  3.0  11.0
# corpoca01   0.0  0.0  14   37.0  0.0  3.0  1.0  2.0   3.0
# dominma01   0.0  1.0  29  125.0  2.0  5.0  2.0  7.0  23.0
#
# [5 rows x 21 columns]

# %%
baseball_15.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...   RBI  \
# playerID                                                         ...
# altuvjo01    2015      1    HOU   AL  154  638  86  200  40   4  ...  66.0
# cartech02    2015      1    HOU   AL  129  391  50   78  17   0  ...  64.0
# castrja01    2015      1    HOU   AL  104  337  38   71  19   0  ...  31.0
# congeha01    2015      1    HOU   AL   73  201  25   46  11   0  ...  33.0
# correca01    2015      1    HOU   AL   99  387  52  108  22   1  ...  68.0
#
#              SB    CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  38.0  13.0  33   67.0  8.0  9.0  3.0  6.0  17.0
# cartech02   1.0   2.0  57  151.0  1.0  6.0  0.0  5.0   5.0
# castrja01   0.0   0.0  33  115.0  1.0  2.0  0.0  3.0   5.0
# congeha01   0.0   1.0  23   63.0  0.0  2.0  1.0  2.0   6.0
# correca01  14.0   4.0  40   78.0  2.0  1.0  0.0  4.0  10.0
#
# [5 rows x 21 columns]

# %%
baseball_16.head()
# Out:
#            yearID  stint teamID lgID    G   AB    R    H  2B  3B  ...   RBI  \
# playerID                                                          ...
# altuvjo01    2016      1    HOU   AL  161  640  108  216  42   5  ...  96.0
# bregmal01    2016      1    HOU   AL   49  201   31   53  13   3  ...  34.0
# castrja01    2016      1    HOU   AL  113  329   41   69  16   3  ...  32.0
# correca01    2016      1    HOU   AL  153  577   76  158  36   3  ...  96.0
# gattiev01    2016      1    HOU   AL  128  447   58  112  19   0  ...  72.0
#
#              SB    CS  BB     SO   IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  30.0  10.0  60   70.0  11.0  7.0  3.0  7.0  15.0
# bregmal01   2.0   0.0  15   52.0   0.0  0.0  0.0  1.0   1.0
# castrja01   2.0   1.0  45  123.0   0.0  1.0  1.0  0.0   9.0
# correca01  13.0   3.0  75  139.0   5.0  5.0  0.0  3.0  12.0
# gattiev01   2.0   1.0  43  127.0   6.0  4.0  0.0  5.0  12.0
#
# [5 rows x 21 columns]

# %%
baseball_14.shape
# Out:
# (16, 21)

# %%
baseball_15.shape
# Out:
# (15, 21)

# %%
baseball_16.shape
# Out:
# (16, 21)

# %%
#Use the difference method to discover the index that are in baseball_14 and not in baseball_15 and vice versa:
baseball_14.index.difference(baseball_15)
# Out:
# Index(['altuvjo01', 'cartech02', 'castrja01', 'corpoca01', 'dominma01',
#        'fowlede01', 'gonzama01', 'grossro01', 'guzmaje01', 'hoeslj01',
#        'krausma01', 'marisja01', 'preslal01', 'singljo02', 'springe01',
#        'villajo01'],
#       dtype='object', name='playerID')

# %%
baseball_14.index.difference(baseball_16)
# Out:
# Index(['altuvjo01', 'cartech02', 'castrja01', 'corpoca01', 'dominma01',
#        'fowlede01', 'gonzama01', 'grossro01', 'guzmaje01', 'hoeslj01',
#        'krausma01', 'marisja01', 'preslal01', 'singljo02', 'springe01',
#        'villajo01'],
#       dtype='object', name='playerID')

# %%
#How many hits each player has over the three year period
hits_14 = baseball_14['H']
hits_15 = baseball_15['H']
hits_16 = baseball_16['H']

# %%
hits_14.head()
# Out:
# playerID
# altuvjo01    225
# cartech02    115
# castrja01    103
# corpoca01     40
# dominma01    121
# Name: H, dtype: int64

# %%
hits_15.head()
# Out:
# playerID
# altuvjo01    200
# cartech02     78
# castrja01     71
# congeha01     46
# correca01    108
# Name: H, dtype: int64

# %%
hits_16.sample(5)
# Out:
# playerID
# gourryu01     34
# correca01    158
# tuckepr01     22
# rasmuco01     76
# castrja01     69
# Name: H, dtype: int64

# %%
#Let us add the two Series over the two years' period:
total_hits = (hits_14 + hits_15).head()
total_hits.sample(5)
# Out:
# playerID
# congeha01      NaN
# cartech02    193.0
# castrja01    174.0
# corpoca01      NaN
# altuvjo01    425.0
# Name: H, dtype: float64

# %%
#Cartesian product - Stacking of series with different indices
#If the values in the indices are missing, and they are being combined, they will be dropped fully

# %%
total_hits.shape
# Out:
# (5,)

# %%
#Checking the number of missing values of the elements above:
total_hits.isnull().sum()
# Out:
# 2

# %%
#To sort the the missing values, the following code could have instead been used:
hits_14.add(hits_15, fill_value = 0).head()
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01     46.0
# corpoca01     40.0
# Name: H, dtype: float64

# %%
#We can use the chaining method to find the sum of the hits for the three years:
three_yr_hits = hits_14.add(hits_15, fill_value = 0)\
                       .add(hits_16, fill_value = 0)
three_yr_hits.head()
# Out:
# playerID
# altuvjo01    641.0
# bregmal01     53.0
# cartech02    193.0
# castrja01    243.0
# congeha01     46.0
# Name: H, dtype: float64

# %%
#Confirming that there are no missing values:
three_yr_hits.isnull().sum()
# Out:
# 0

# %%
#Alternatively:
three_yr_hits.hasnans
# Out:
# False

# %%
#Let us select a few columns from the 2014 baseball dataset:
df_14 = baseball_14[['G', 'AB', 'R', 'H']]
df_14.head()
# Out:
#              G   AB   R    H
# playerID
# altuvjo01  158  660  85  225
# cartech02  145  507  68  115
# castrja01  126  465  43  103
# corpoca01   55  170  22   40
# dominma01  157  564  51  121

# %%
#Let us select a few features from the 2015 baseball dataset:
df_15 = baseball_15[['AB', 'R', 'H', 'HR']]
df_15.head()
# Out:
#             AB   R    H  HR
# playerID
# altuvjo01  638  86  200  15
# cartech02  391  50   78  24
# castrja01  337  38   71  11
# congeha01  201  25   46  11
# correca01  387  52  108  22

# %%
#Adding the two DataFrames and highliting null elements in red:
#Rows with playerID appearing in both DataFrames will be non-missing
(df_14 + df_15).head(10).style.highlight_null('brown')
# Out:
# <style type="text/css">
# #T_29434_row0_col1, #T_29434_row0_col3, #T_29434_row1_col1, #T_29434_row1_col3, #T_29434_row2_col1, #T_29434_row2_col3, #T_29434_row3_col0, #T_29434_row3_col1, #T_29434_row3_col2, #T_29434_row3_col3, #T_29434_row3_col4, #T_29434_row4_col0, #T_29434_row4_col1, #T_29434_row4_col2, #T_29434_row4_col3, #T_29434_row4_col4, #T_29434_row5_col0, #T_29434_row5_col1, #T_29434_row5_col2, #T_29434_row5_col3, #T_29434_row5_col4, #T_29434_row6_col0, #T_29434_row6_col1, #T_29434_row6_col2, #T_29434_row6_col3, #T_29434_row6_col4, #T_29434_row7_col0, #T_29434_row7_col1, #T_29434_row7_col2, #T_29434_row7_col3, #T_29434_row7_col4, #T_29434_row8_col0, #T_29434_row8_col1, #T_29434_row8_col2, #T_29434_row8_col3, #T_29434_row8_col4, #T_29434_row9_col0, #T_29434_row9_col1, #T_29434_row9_col2, #T_29434_row9_col3, #T_29434_row9_col4 {
#   background-color: brown;
# }
# </style>
# <table id="T_29434_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >AB</th>
#       <th class="col_heading level0 col1" >G</th>
#       <th class="col_heading level0 col2" >H</th>
#       <th class="col_heading level0 col3" >HR</th>
#       <th class="col_heading level0 col4" >R</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >playerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29434_level0_row0" class="row_heading level0 row0" >altuvjo01</th>
#       <td id="T_29434_row0_col0" class="data row0 col0" >1298.000000</td>
#       <td id="T_29434_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_29434_row0_col2" class="data row0 col2" >425.000000</td>
#       <td id="T_29434_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_29434_row0_col4" class="data row0 col4" >171.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row1" class="row_heading level0 row1" >cartech02</th>
#       <td id="T_29434_row1_col0" class="data row1 col0" >898.000000</td>
#       <td id="T_29434_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_29434_row1_col2" class="data row1 col2" >193.000000</td>
#       <td id="T_29434_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_29434_row1_col4" class="data row1 col4" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row2" class="row_heading level0 row2" >castrja01</th>
#       <td id="T_29434_row2_col0" class="data row2 col0" >802.000000</td>
#       <td id="T_29434_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_29434_row2_col2" class="data row2 col2" >174.000000</td>
#       <td id="T_29434_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_29434_row2_col4" class="data row2 col4" >81.000000</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row3" class="row_heading level0 row3" >congeha01</th>
#       <td id="T_29434_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_29434_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_29434_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_29434_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_29434_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row4" class="row_heading level0 row4" >corpoca01</th>
#       <td id="T_29434_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_29434_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_29434_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_29434_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_29434_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row5" class="row_heading level0 row5" >correca01</th>
#       <td id="T_29434_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_29434_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_29434_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_29434_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_29434_row5_col4" class="data row5 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row6" class="row_heading level0 row6" >dominma01</th>
#       <td id="T_29434_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_29434_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_29434_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_29434_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_29434_row6_col4" class="data row6 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row7" class="row_heading level0 row7" >fowlede01</th>
#       <td id="T_29434_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_29434_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_29434_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_29434_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_29434_row7_col4" class="data row7 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row8" class="row_heading level0 row8" >gattiev01</th>
#       <td id="T_29434_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_29434_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_29434_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_29434_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_29434_row8_col4" class="data row8 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_29434_level0_row9" class="row_heading level0 row9" >gomezca01</th>
#       <td id="T_29434_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_29434_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_29434_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_29434_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_29434_row9_col4" class="data row9 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
#The fill_value method will also result in missing values for the combination of rows and columns is not in our input data
#AB, H, and R are the only columns that appear in both DataFrames
#For example, the intersection of playerID congeha01 and column G.
#He only appeared in the 2015 dataset that did not have the G column. Therefore, no value was filled with it:
df_14.add(df_15, fill_value = 0).head(10).style.highlight_null('red')
# Out:
# <style type="text/css">
# #T_ae302_row3_col1, #T_ae302_row4_col3, #T_ae302_row5_col1, #T_ae302_row6_col3, #T_ae302_row7_col3, #T_ae302_row8_col1, #T_ae302_row9_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_ae302_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >AB</th>
#       <th class="col_heading level0 col1" >G</th>
#       <th class="col_heading level0 col2" >H</th>
#       <th class="col_heading level0 col3" >HR</th>
#       <th class="col_heading level0 col4" >R</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >playerID</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae302_level0_row0" class="row_heading level0 row0" >altuvjo01</th>
#       <td id="T_ae302_row0_col0" class="data row0 col0" >1298.000000</td>
#       <td id="T_ae302_row0_col1" class="data row0 col1" >158.000000</td>
#       <td id="T_ae302_row0_col2" class="data row0 col2" >425.000000</td>
#       <td id="T_ae302_row0_col3" class="data row0 col3" >15.000000</td>
#       <td id="T_ae302_row0_col4" class="data row0 col4" >171.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row1" class="row_heading level0 row1" >cartech02</th>
#       <td id="T_ae302_row1_col0" class="data row1 col0" >898.000000</td>
#       <td id="T_ae302_row1_col1" class="data row1 col1" >145.000000</td>
#       <td id="T_ae302_row1_col2" class="data row1 col2" >193.000000</td>
#       <td id="T_ae302_row1_col3" class="data row1 col3" >24.000000</td>
#       <td id="T_ae302_row1_col4" class="data row1 col4" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row2" class="row_heading level0 row2" >castrja01</th>
#       <td id="T_ae302_row2_col0" class="data row2 col0" >802.000000</td>
#       <td id="T_ae302_row2_col1" class="data row2 col1" >126.000000</td>
#       <td id="T_ae302_row2_col2" class="data row2 col2" >174.000000</td>
#       <td id="T_ae302_row2_col3" class="data row2 col3" >11.000000</td>
#       <td id="T_ae302_row2_col4" class="data row2 col4" >81.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row3" class="row_heading level0 row3" >congeha01</th>
#       <td id="T_ae302_row3_col0" class="data row3 col0" >201.000000</td>
#       <td id="T_ae302_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_ae302_row3_col2" class="data row3 col2" >46.000000</td>
#       <td id="T_ae302_row3_col3" class="data row3 col3" >11.000000</td>
#       <td id="T_ae302_row3_col4" class="data row3 col4" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row4" class="row_heading level0 row4" >corpoca01</th>
#       <td id="T_ae302_row4_col0" class="data row4 col0" >170.000000</td>
#       <td id="T_ae302_row4_col1" class="data row4 col1" >55.000000</td>
#       <td id="T_ae302_row4_col2" class="data row4 col2" >40.000000</td>
#       <td id="T_ae302_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_ae302_row4_col4" class="data row4 col4" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row5" class="row_heading level0 row5" >correca01</th>
#       <td id="T_ae302_row5_col0" class="data row5 col0" >387.000000</td>
#       <td id="T_ae302_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_ae302_row5_col2" class="data row5 col2" >108.000000</td>
#       <td id="T_ae302_row5_col3" class="data row5 col3" >22.000000</td>
#       <td id="T_ae302_row5_col4" class="data row5 col4" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row6" class="row_heading level0 row6" >dominma01</th>
#       <td id="T_ae302_row6_col0" class="data row6 col0" >564.000000</td>
#       <td id="T_ae302_row6_col1" class="data row6 col1" >157.000000</td>
#       <td id="T_ae302_row6_col2" class="data row6 col2" >121.000000</td>
#       <td id="T_ae302_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_ae302_row6_col4" class="data row6 col4" >51.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row7" class="row_heading level0 row7" >fowlede01</th>
#       <td id="T_ae302_row7_col0" class="data row7 col0" >434.000000</td>
#       <td id="T_ae302_row7_col1" class="data row7 col1" >116.000000</td>
#       <td id="T_ae302_row7_col2" class="data row7 col2" >120.000000</td>
#       <td id="T_ae302_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_ae302_row7_col4" class="data row7 col4" >61.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row8" class="row_heading level0 row8" >gattiev01</th>
#       <td id="T_ae302_row8_col0" class="data row8 col0" >566.000000</td>
#       <td id="T_ae302_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_ae302_row8_col2" class="data row8 col2" >139.000000</td>
#       <td id="T_ae302_row8_col3" class="data row8 col3" >27.000000</td>
#       <td id="T_ae302_row8_col4" class="data row8 col4" >66.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ae302_level0_row9" class="row_heading level0 row9" >gomezca01</th>
#       <td id="T_ae302_row9_col0" class="data row9 col0" >149.000000</td>
#       <td id="T_ae302_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_ae302_row9_col2" class="data row9 col2" >36.000000</td>
#       <td id="T_ae302_row9_col3" class="data row9 col3" >4.000000</td>
#       <td id="T_ae302_row9_col4" class="data row9 col4" >19.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## <u>Appending columns from different DataFrames</u>
# <p>The indexes must first align before the two or more Series or DataFrames are combined. Here, we will use the employees
# dataset to append a new column containing the maximum salary of an employee in that department</p>

# %%
employee = pd.read_csv('data/employee.csv')
employee.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# 2  2015-02-03  2015-02-03
# 3  1982-02-08  1991-05-25
# 4  1989-06-19  1994-10-22

# %%
#Filtering the DEPARTMENT and BASE_SALARY features
dept_sal = employee[['DEPARTMENT', 'BASE_SALARY']]

# %%
dept_sal.head()
# Out:
#                       DEPARTMENT  BASE_SALARY
# 0    Municipal Courts Department     121862.0
# 1                        Library      26125.0
# 2  Houston Police Department-HPD      45279.0
# 3  Houston Fire Department (HFD)      63166.0
# 4    General Services Department      56347.0

# %%
#Sorting DEPARTMENT from the first to the last and BASE_SALARY from the largest to the smallest:
dept_sal = dept_sal.sort_values(['DEPARTMENT', 'BASE_SALARY'], ascending=[True, False])
dept_sal.head(20)
# Out:
#                       DEPARTMENT  BASE_SALARY
# 1494  Admn. & Regulatory Affairs     140416.0
# 237   Admn. & Regulatory Affairs     130416.0
# 1679  Admn. & Regulatory Affairs     103776.0
# 988   Admn. & Regulatory Affairs      72741.0
# 693   Admn. & Regulatory Affairs      66825.0
# 1868  Admn. & Regulatory Affairs      65000.0
# 971   Admn. & Regulatory Affairs      62129.0
# 1070  Admn. & Regulatory Affairs      57221.0
# 1983  Admn. & Regulatory Affairs      55172.0
# 379   Admn. & Regulatory Affairs      48755.0
# 1022  Admn. & Regulatory Affairs      47585.0
# 1756  Admn. & Regulatory Affairs      47341.0
# 1342  Admn. & Regulatory Affairs      43139.0
# 414   Admn. & Regulatory Affairs      41434.0
# 1187  Admn. & Regulatory Affairs      37710.0
# 1439  Admn. & Regulatory Affairs      36400.0
# 1015  Admn. & Regulatory Affairs      36088.0
# 589   Admn. & Regulatory Affairs      35318.0
# 290   Admn. & Regulatory Affairs      35152.0
# 768   Admn. & Regulatory Affairs      34986.0

# %%
#Use the drop_duplicates method to keep the first row of each department
max_dept_sal = dept_sal.drop_duplicates(subset='DEPARTMENT')
max_dept_sal.head()
# Out:
#                         DEPARTMENT  BASE_SALARY
# 1494    Admn. & Regulatory Affairs     140416.0
# 149       City Controller's Office      64251.0
# 236                   City Council     100000.0
# 647   Convention and Entertainment      38397.0
# 1500   Dept of Neighborhoods (DON)      89221.0

# %%
max_dept_sal['DEPARTMENT'].value_counts()
# Out:
# Admn. & Regulatory Affairs        1
# City Controller's Office          1
# Public Works & Engineering-PWE    1
# Planning & Development            1
# Parks & Recreation                1
# Municipal Courts Department       1
# Mayor's Office                    1
# Library                           1
# Legal Department                  1
# Human Resources Dept.             1
# Houston Police Department-HPD     1
# Houston Information Tech Svcs     1
# Houston Fire Department (HFD)     1
# Houston Emergency Center (HEC)    1
# Houston Airport System (HAS)      1
# Housing and Community Devp.       1
# Health & Human Services           1
# General Services Department       1
# Fleet Management Department       1
# Finance                           1
# Dept of Neighborhoods (DON)       1
# Convention and Entertainment      1
# City Council                      1
# Solid Waste Management            1
# Name: DEPARTMENT, dtype: int64

# %%
dept_sal['DEPARTMENT'].value_counts()
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Parks & Recreation                 74
# Solid Waste Management             43
# Fleet Management Department        36
# Library                            36
# Admn. & Regulatory Affairs         29
# Municipal Courts Department        28
# Human Resources Dept.              24
# Houston Emergency Center (HEC)     23
# Housing and Community Devp.        22
# General Services Department        22
# Dept of Neighborhoods (DON)        17
# Legal Department                   17
# City Council                       11
# Finance                            10
# Houston Information Tech Svcs       9
# Planning & Development              7
# City Controller's Office            5
# Mayor's Office                      5
# Convention and Entertainment        1
# Name: DEPARTMENT, dtype: int64

# %%
#x = []
#x.append(dept_sal['DEPARTMENT'].unique())
#x.value_count()

# %%
#Put the department column into the index of both DataFrames
max_dept_sal = max_dept_sal.set_index('DEPARTMENT')
employee = employee.set_index('DEPARTMENT')

# %%
employee['MAX_DEPT_SALARY'] = max_dept_sal['BASE_SALARY']
employee.sample(30)
# Out:
#                                 UNIQUE_ID  \
# DEPARTMENT
# Houston Police Department-HPD        1382
# Houston Police Department-HPD        1904
# Housing and Community Devp.          1049
# Houston Police Department-HPD        1995
# Houston Police Department-HPD          89
# Public Works & Engineering-PWE       1858
# Houston Police Department-HPD         765
# Public Works & Engineering-PWE       1297
# Houston Police Department-HPD         814
# Health & Human Services               918
# Houston Police Department-HPD        1115
# General Services Department          1702
# Houston Police Department-HPD         278
# Houston Police Department-HPD         936
# Admn. & Regulatory Affairs            991
# Health & Human Services               111
# Houston Airport System (HAS)         1943
# Houston Police Department-HPD        1628
# Houston Airport System (HAS)         1253
# Houston Police Department-HPD         332
# Houston Police Department-HPD        1970
# Fleet Management Department          1443
# Houston Fire Department (HFD)         189
# Houston Police Department-HPD         161
# Houston Fire Department (HFD)        1773
# Houston Police Department-HPD        1203
# Houston Police Department-HPD         266
# Human Resources Dept.                1607
# Houston Police Department-HPD        1910
# General Services Department          1524
#
#                                                       POSITION_TITLE  \
# DEPARTMENT
# Houston Police Department-HPD                  SENIOR POLICE OFFICER
# Houston Police Department-HPD                         JAIL ATTENDANT
# Housing and Community Devp.                     FINANCIAL ANALYST IV
# Houston Police Department-HPD                         POLICE OFFICER
# Houston Police Department-HPD                  SENIOR POLICE OFFICER
# Public Works & Engineering-PWE              ADMINISTRATIVE ASSISTANT
# Houston Police Department-HPD                        POLICE SERGEANT
# Public Works & Engineering-PWE     SENIOR INVENTORY MANAGEMENT CLERK
# Houston Police Department-HPD                  SENIOR POLICE OFFICER
# Health & Human Services                         FINANCIAL ANALYST IV
# Houston Police Department-HPD                         POLICE OFFICER
# General Services Department                 MAINTENANCE MECHANIC III
# Houston Police Department-HPD                  SENIOR POLICE OFFICER
# Houston Police Department-HPD                 OFFICE SERVICE MANAGER
# Admn. & Regulatory Affairs               PARKING ENFORCEMENT OFFICER
# Health & Human Services                   SENIOR DATA ENTRY OPERATOR
# Houston Airport System (HAS)    ASSISTANT DIRECTOR (EXECUTIVE LEVEL)
# Houston Police Department-HPD                  SENIOR POLICE OFFICER
# Houston Airport System (HAS)                               INSPECTOR
# Houston Police Department-HPD                  SENIOR POLICE OFFICER
# Houston Police Department-HPD                  SENIOR POLICE OFFICER
# Fleet Management Department                               MECHANIC I
# Houston Fire Department (HFD)                           FIRE FIGHTER
# Houston Police Department-HPD                         POLICE OFFICER
# Houston Fire Department (HFD)                    SENIOR INVESTIGATOR
# Houston Police Department-HPD            POLICE OFFICER,PROBATIONARY
# Houston Police Department-HPD                         POLICE OFFICER
# Human Resources Dept.                      HUMAN RESOURCES ASSISTANT
# Houston Police Department-HPD                        POLICE SERGEANT
# General Services Department                     FINANCIAL ANALYST IV
#
#                                 BASE_SALARY                       RACE  \
# DEPARTMENT
# Houston Police Department-HPD       66614.0                      White
# Houston Police Department-HPD       37211.0  Black or African American
# Housing and Community Devp.         70832.0     Asian/Pacific Islander
# Houston Police Department-HPD       43443.0                      White
# Houston Police Department-HPD       66614.0            Hispanic/Latino
# Public Works & Engineering-PWE      38750.0  Black or African American
# Houston Police Department-HPD       81239.0            Hispanic/Latino
# Public Works & Engineering-PWE      37357.0  Black or African American
# Houston Police Department-HPD           NaN  Black or African American
# Health & Human Services             70762.0  Black or African American
# Houston Police Department-HPD       60347.0  Black or African American
# General Services Department         39166.0            Hispanic/Latino
# Houston Police Department-HPD       66614.0            Hispanic/Latino
# Houston Police Department-HPD       60653.0  Black or African American
# Admn. & Regulatory Affairs          27581.0                        NaN
# Health & Human Services             31554.0     Asian/Pacific Islander
# Houston Airport System (HAS)       128606.0                      White
# Houston Police Department-HPD       66614.0  Black or African American
# Houston Airport System (HAS)        54080.0                      White
# Houston Police Department-HPD           NaN                      White
# Houston Police Department-HPD       66614.0            Hispanic/Latino
# Fleet Management Department         32406.0            Hispanic/Latino
# Houston Fire Department (HFD)       57815.0                      White
# Houston Police Department-HPD       47650.0            Hispanic/Latino
# Houston Fire Department (HFD)       74270.0            Hispanic/Latino
# Houston Police Department-HPD       42000.0     Asian/Pacific Islander
# Houston Police Department-HPD       55461.0  Black or African American
# Human Resources Dept.               40560.0                      White
# Houston Police Department-HPD       81239.0                      White
# General Services Department         74192.0                      White
#
#                                EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# DEPARTMENT
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time  Female            Active
# Housing and Community Devp.          Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Public Works & Engineering-PWE       Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Health & Human Services              Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# General Services Department          Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Admn. & Regulatory Affairs           Full Time    Male            Active
# Health & Human Services              Full Time  Female            Active
# Houston Airport System (HAS)         Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Airport System (HAS)         Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Fleet Management Department          Full Time    Male            Active
# Houston Fire Department (HFD)        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Fire Department (HFD)        Full Time    Male            Active
# Houston Police Department-HPD        Full Time    Male            Active
# Houston Police Department-HPD        Full Time  Female            Active
# Human Resources Dept.                Full Time  Female            Active
# Houston Police Department-HPD        Full Time    Male            Active
# General Services Department          Full Time    Male            Active
#
#                                  HIRE_DATE    JOB_DATE  MAX_DEPT_SALARY
# DEPARTMENT
# Houston Police Department-HPD   1972-11-13  2002-01-05         199596.0
# Houston Police Department-HPD   2008-05-05  2008-05-05         199596.0
# Housing and Community Devp.     2010-04-05  2014-12-20          98536.0
# Houston Police Department-HPD   2014-06-09  2015-06-09         199596.0
# Houston Police Department-HPD   1985-05-28  2002-09-14         199596.0
# Public Works & Engineering-PWE  2014-10-27  2015-09-26         178331.0
# Houston Police Department-HPD   1994-11-07  2002-02-28         199596.0
# Public Works & Engineering-PWE  1993-10-02  2011-07-23         178331.0
# Houston Police Department-HPD   1984-01-09  2004-06-05         199596.0
# Health & Human Services         1998-09-08  2008-08-23         180416.0
# Houston Police Department-HPD   1998-08-31  1999-08-31         199596.0
# General Services Department     2008-01-02  2008-01-02          89194.0
# Houston Police Department-HPD   1996-10-28  2011-10-01         199596.0
# Houston Police Department-HPD   2005-10-20  2012-12-22         199596.0
# Admn. & Regulatory Affairs      2016-02-11  2016-02-11         140416.0
# Health & Human Services         1993-10-18  2006-09-02         180416.0
# Houston Airport System (HAS)    1993-02-22  2004-09-04         186192.0
# Houston Police Department-HPD   1993-06-21  2006-12-30         199596.0
# Houston Airport System (HAS)    2013-01-28  2013-01-28         186192.0
# Houston Police Department-HPD   1985-07-22  2015-10-10         199596.0
# Houston Police Department-HPD   1990-06-11  2002-12-07         199596.0
# Fleet Management Department     2007-11-05  2007-11-05         125884.0
# Houston Fire Department (HFD)   2001-12-26  2003-01-04         210588.0
# Houston Police Department-HPD   2012-06-25  2013-06-25         199596.0
# Houston Fire Department (HFD)   1999-11-15  2013-07-10         210588.0
# Houston Police Department-HPD   2015-10-12  2016-04-27         199596.0
# Houston Police Department-HPD   2007-08-13  2008-02-26         199596.0
# Human Resources Dept.           2007-08-13  2011-07-09         110547.0
# Houston Police Department-HPD   1985-03-04  1994-05-21         199596.0
# General Services Department     2005-09-19  2005-09-19          89194.0

# %%
employee.query('BASE_SALARY > MAX_DEPT_SALARY')
# Out:
# Empty DataFrame
# Columns: [UNIQUE_ID, POSITION_TITLE, BASE_SALARY, RACE, EMPLOYMENT_TYPE, GENDER, EMPLOYMENT_STATUS, HIRE_DATE, JOB_DATE, MAX_DEPT_SALARY]
# Index: []

# %%
employee['MAX_DEPT_SALARY'].sample(15)
# Out:
# DEPARTMENT
# Houston Police Department-HPD     199596.0
# Public Works & Engineering-PWE    178331.0
# Houston Fire Department (HFD)     210588.0
# Public Works & Engineering-PWE    178331.0
# Public Works & Engineering-PWE    178331.0
# Public Works & Engineering-PWE    178331.0
# Houston Airport System (HAS)      186192.0
# Houston Police Department-HPD     199596.0
# Houston Fire Department (HFD)     210588.0
# Houston Airport System (HAS)      186192.0
# Public Works & Engineering-PWE    178331.0
# Public Works & Engineering-PWE    178331.0
# Houston Fire Department (HFD)     210588.0
# Human Resources Dept.             110547.0
# Houston Airport System (HAS)      186192.0
# Name: MAX_DEPT_SALARY, dtype: float64

# %% [markdown]
# ## <u>Highlighting the maximum value from each column</u>
# <p>This procedure discovers the school that has maximum values for each numeric column and styles the DataFrame to highlight
# the information so that it is easily consumed by a user</p>

# %%
college = pd.read_csv('data/college.csv', index_col = 'INSTNM')
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                      ...
# Alabama A & M University                      0.0   4206.0  ...     0.0000
# University of Alabama at Birmingham           0.0  11383.0  ...     0.0368
# Amridge University                            1.0    291.0  ...     0.0000
# University of Alabama in Huntsville           0.0   5451.0  ...     0.0172
# Alabama State University                      0.0   4811.0  ...     0.0098
#
#                                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# Alabama A & M University               0.0059     0.0138    0.0656         1
# University of Alabama at Birmingham    0.0179     0.0100    0.2607         1
# Amridge University                     0.0000     0.2715    0.4536         1
# University of Alabama in Huntsville    0.0332     0.0350    0.2146         1
# Alabama State University               0.0243     0.0137    0.0892         1
#
#                                      PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University              0.7356    0.8284   0.1049
# University of Alabama at Birmingham   0.3460    0.5214   0.2422
# Amridge University                    0.6801    0.7795   0.8540
# University of Alabama in Huntsville   0.3072    0.4596   0.2640
# Alabama State University              0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                       30300               33888
# University of Alabama at Birmingham            39700             21941.5
# Amridge University                             40100               23370
# University of Alabama in Huntsville            45500               24097
# Alabama State University                       26600             33118.5
#
# [5 rows x 26 columns]

# %%
college.dtypes
# Out:
# CITY                   object
# STABBR                 object
# HBCU                  float64
# MENONLY               float64
# WOMENONLY             float64
# RELAFFIL                int64
# SATVRMID              float64
# SATMTMID              float64
# DISTANCEONLY          float64
# UGDS                  float64
# UGDS_WHITE            float64
# UGDS_BLACK            float64
# UGDS_HISP             float64
# UGDS_ASIAN            float64
# UGDS_AIAN             float64
# UGDS_NHPI             float64
# UGDS_2MOR             float64
# UGDS_NRA              float64
# UGDS_UNKN             float64
# PPTUG_EF              float64
# CURROPER                int64
# PCTPELL               float64
# PCTFLOAN              float64
# UG25ABV               float64
# MD_EARN_WNE_P10        object
# GRAD_DEBT_MDN_SUPP     object
# dtype: object

# %%
college.dtypes.value_counts()
# Out:
# float64    20
# object      4
# int64       2
# dtype: int64

# %%
college.shape
# Out:
# (7535, 26)

# %%
#All the other columns besides CITY and STABBR appear to be numeric
#the MD_EARN_WNE_P10 and GRAD_DEBT_MDN_SUPP columns are of type object and not numeric.
#We can do a sample data to confirm this:
college['MD_EARN_WNE_P10'].iloc[0]
# Out:
# '30300'

# %%
college['GRAD_DEBT_MDN_SUPP'].iloc[0]
# Out:
# '33888'

# %%
#Some values are strings but we would like them to be numeric
#To confirm the presence of non-numeric elements in the data:
college.MD_EARN_WNE_P10.sort_values(ascending = True).head()
# Out:
# INSTNM
# Associated Beth Rivkah Schools                       10100
# Rosemead Beauty School                               10100
# Adrian's College of Beauty Turlock                   10400
# University of California-Hastings College of Law    104800
# University of Texas Southwestern Medical Center     106900
# Name: MD_EARN_WNE_P10, dtype: object

# %%
#Some schools have privacy concerns about the data. 
#To force these columns to be numeric, we may use the to_numeric method:
#The coerce parsing reduces errors that arise during this process
cols = ['MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']
for col in cols:
    college[col] = pd.to_numeric(college[col], errors = 'coerce')

# %%
college.dtypes.loc[cols]
# Out:
# MD_EARN_WNE_P10       float64
# GRAD_DEBT_MDN_SUPP    float64
# dtype: object

# %%
college.MD_EARN_WNE_P10.sort_values(ascending = False).head()
# Out:
# INSTNM
# Medical College of Wisconsin                            233100.0
# West Virginia School of Osteopathic Medicine            219900.0
# A T Still University of Health Sciences                 219800.0
# Albany Medical College                                  214400.0
# University of Massachusetts Medical School Worcester    213600.0
# Name: MD_EARN_WNE_P10, dtype: float64

# %%
college.describe(include = [np.number])
# Out:
#               HBCU      MENONLY    WOMENONLY     RELAFFIL     SATVRMID  \
# count  7164.000000  7164.000000  7164.000000  7535.000000  1185.000000
# mean      0.014238     0.009213     0.005304     0.190975   522.819409
# std       0.118478     0.095546     0.072642     0.393096    68.578862
# min       0.000000     0.000000     0.000000     0.000000   290.000000
# 25%       0.000000     0.000000     0.000000     0.000000   475.000000
# 50%       0.000000     0.000000     0.000000     0.000000   510.000000
# 75%       0.000000     0.000000     0.000000     0.000000   555.000000
# max       1.000000     1.000000     1.000000     1.000000   765.000000
#
#           SATMTMID  DISTANCEONLY           UGDS   UGDS_WHITE   UGDS_BLACK  \
# count  1196.000000   7164.000000    6874.000000  6874.000000  6874.000000
# mean    530.765050      0.005583    2356.837940     0.510207     0.189997
# std      73.469767      0.074519    5474.275871     0.286958     0.224587
# min     310.000000      0.000000       0.000000     0.000000     0.000000
# 25%     482.000000      0.000000     117.000000     0.267500     0.036125
# 50%     520.000000      0.000000     412.500000     0.555700     0.100050
# 75%     565.000000      0.000000    1929.500000     0.747875     0.257700
# max     785.000000      1.000000  151558.000000     1.000000     1.000000
#
#        ...    UGDS_2MOR     UGDS_NRA    UGDS_UNKN     PPTUG_EF     CURROPER  \
# count  ...  6874.000000  6874.000000  6874.000000  6853.000000  7535.000000
# mean   ...     0.023950     0.016086     0.045181     0.226639     0.923291
# std    ...     0.031288     0.050172     0.093440     0.246470     0.266146
# min    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    ...     0.000000     0.000000     0.000000     0.000000     1.000000
# 50%    ...     0.017500     0.000000     0.014300     0.150400     1.000000
# 75%    ...     0.033900     0.011700     0.045400     0.376900     1.000000
# max    ...     0.533300     0.928600     0.902700     1.000000     1.000000
#
#            PCTPELL     PCTFLOAN      UG25ABV  MD_EARN_WNE_P10  \
# count  6849.000000  6849.000000  6718.000000      5591.000000
# mean      0.530643     0.522211     0.410021     32918.315149
# std       0.225544     0.283616     0.228939     14621.845375
# min       0.000000     0.000000     0.000000      9500.000000
# 25%       0.357800     0.332900     0.241500     23900.000000
# 50%       0.521500     0.583300     0.400750     30700.000000
# 75%       0.712900     0.745000     0.572275     38800.000000
# max       1.000000     1.000000     1.000000    233100.000000
#
#        GRAD_DEBT_MDN_SUPP
# count         5993.000000
# mean         16850.668530
# std           8401.582396
# min           1409.000000
# 25%           9500.000000
# 50%          14500.000000
# 75%          24547.500000
# max          49750.000000
#
# [8 rows x 24 columns]

# %%
#Use the select_dtypes method to filter for only numeric columns.
#This will exclude STABBR and CITY columns, where a maximum value does not make sense with this problem:
college_n = college.select_dtypes(include = [np.number])
college_n.head()
# Out:
#                                      HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Alabama A & M University              1.0      0.0        0.0         0
# University of Alabama at Birmingham   0.0      0.0        0.0         0
# Amridge University                    0.0      0.0        0.0         1
# University of Alabama in Huntsville   0.0      0.0        0.0         0
# Alabama State University              1.0      0.0        0.0         0
#
#                                      SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Alabama A & M University                424.0     420.0           0.0
# University of Alabama at Birmingham     570.0     565.0           0.0
# Amridge University                        NaN       NaN           1.0
# University of Alabama in Huntsville     595.0     590.0           0.0
# Alabama State University                425.0     430.0           0.0
#
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  ...  \
# INSTNM                                                                ...
# Alabama A & M University              4206.0      0.0333      0.9353  ...
# University of Alabama at Birmingham  11383.0      0.5922      0.2600  ...
# Amridge University                     291.0      0.2990      0.4192  ...
# University of Alabama in Huntsville   5451.0      0.6988      0.1255  ...
# Alabama State University              4811.0      0.0158      0.9208  ...
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138    0.0656
# University of Alabama at Birmingham     0.0368    0.0179     0.0100    0.2607
# Amridge University                      0.0000    0.0000     0.2715    0.4536
# University of Alabama in Huntsville     0.0172    0.0332     0.0350    0.2146
# Alabama State University                0.0098    0.0243     0.0137    0.0892
#
#                                      CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University                    1   0.7356    0.8284   0.1049
# University of Alabama at Birmingham         1   0.3460    0.5214   0.2422
# Amridge University                          1   0.6801    0.7795   0.8540
# University of Alabama in Huntsville         1   0.3072    0.4596   0.2640
# Alabama State University                    1   0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 24 columns]

# %%
#To find data that may have only binary values:
criteria = college_n.nunique() == 2
criteria.head()
# Out:
# HBCU          True
# MENONLY       True
# WOMENONLY     True
# RELAFFIL      True
# SATVRMID     False
# dtype: bool

# %%
binary_cols = college_n.columns[criteria].tolist()
binary_cols
# Out:
# ['HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'DISTANCEONLY', 'CURROPER']

# %%
#Drop the binary columns with the drop method:
college_n2 = college_n.drop(labels = binary_cols, axis = 'columns')
college_n2.head()
# Out:
#                                      SATVRMID  SATMTMID     UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                424.0     420.0   4206.0      0.0333
# University of Alabama at Birmingham     570.0     565.0  11383.0      0.5922
# Amridge University                        NaN       NaN    291.0      0.2990
# University of Alabama in Huntsville     595.0     590.0   5451.0      0.6988
# Alabama State University                425.0     430.0   4811.0      0.0158
#
#                                      UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                 0.9353     0.0055      0.0019
# University of Alabama at Birmingham      0.2600     0.0283      0.0518
# Amridge University                       0.4192     0.0069      0.0034
# University of Alabama in Huntsville      0.1255     0.0382      0.0376
# Alabama State University                 0.9208     0.0121      0.0019
#
#                                      UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Alabama A & M University                0.0024     0.0019     0.0000
# University of Alabama at Birmingham     0.0022     0.0007     0.0368
# Amridge University                      0.0000     0.0000     0.0000
# University of Alabama in Huntsville     0.0143     0.0002     0.0172
# Alabama State University                0.0010     0.0006     0.0098
#
#                                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  PCTPELL  \
# INSTNM
# Alabama A & M University               0.0059     0.0138    0.0656   0.7356
# University of Alabama at Birmingham    0.0179     0.0100    0.2607   0.3460
# Amridge University                     0.0000     0.2715    0.4536   0.6801
# University of Alabama in Huntsville    0.0332     0.0350    0.2146   0.3072
# Alabama State University               0.0243     0.0137    0.0892   0.7347
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University               0.8284   0.1049          30300.0
# University of Alabama at Birmingham    0.5214   0.2422          39700.0
# Amridge University                     0.7795   0.8540          40100.0
# University of Alabama in Huntsville    0.4596   0.2640          45500.0
# Alabama State University               0.7554   0.1270          26600.0
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                        33888.0
# University of Alabama at Birmingham             21941.5
# Amridge University                              23370.0
# University of Alabama in Huntsville             24097.0
# Alabama State University                        33118.5

# %%
college_n2.shape
# Out:
# (7535, 18)

# %%
#Use the idxmax method to find the index label of the maximum value for each column:
max_cols = college_n2.idxmax(axis = 0)
max_cols
# Out:
# SATVRMID                             California Institute of Technology
# SATMTMID                             California Institute of Technology
# UGDS                                      University of Phoenix-Arizona
# UGDS_WHITE                       Mr Leon's School of Hair Design-Moscow
# UGDS_BLACK                           Velvatex College of Beauty Culture
# UGDS_HISP                       Thunderbird School of Global Management
# UGDS_ASIAN                          Cosmopolitan Beauty and Tech School
# UGDS_AIAN                             Haskell Indian Nations University
# UGDS_NHPI                                       Palau Community College
# UGDS_2MOR                                                 LIU Brentwood
# UGDS_NRA               California University of Management and Sciences
# UGDS_UNKN             Le Cordon Bleu College of Culinary Arts-San Fr...
# PPTUG_EF                        Thunderbird School of Global Management
# PCTPELL                                        MTI Business College Inc
# PCTFLOAN                                         ABC Beauty College Inc
# UG25ABV                                  Dongguk University-Los Angeles
# MD_EARN_WNE_P10                            Medical College of Wisconsin
# GRAD_DEBT_MDN_SUPP           Southwest University of Visual Arts-Tucson
# dtype: object

# %%
#Getting an ndarray of the unique column names:
unique_max_cols = max_cols.unique()
unique_max_cols
# Out:
# array(['California Institute of Technology',
#        'University of Phoenix-Arizona',
#        "Mr Leon's School of Hair Design-Moscow",
#        'Velvatex College of Beauty Culture',
#        'Thunderbird School of Global Management',
#        'Cosmopolitan Beauty and Tech School',
#        'Haskell Indian Nations University', 'Palau Community College',
#        'LIU Brentwood',
#        'California University of Management and Sciences',
#        'Le Cordon Bleu College of Culinary Arts-San Francisco',
#        'MTI Business College Inc', 'ABC Beauty College Inc',
#        'Dongguk University-Los Angeles', 'Medical College of Wisconsin',
#        'Southwest University of Visual Arts-Tucson'], dtype=object)

# %%
college_n2.loc[unique_max_cols].style.highlight_max()
# Out:
# <style type="text/css">
# #T_5018f_row0_col0, #T_5018f_row0_col1, #T_5018f_row1_col2, #T_5018f_row2_col3, #T_5018f_row3_col4, #T_5018f_row4_col5, #T_5018f_row4_col12, #T_5018f_row5_col6, #T_5018f_row6_col7, #T_5018f_row7_col8, #T_5018f_row8_col9, #T_5018f_row9_col10, #T_5018f_row10_col11, #T_5018f_row11_col13, #T_5018f_row11_col14, #T_5018f_row12_col14, #T_5018f_row13_col15, #T_5018f_row14_col16, #T_5018f_row15_col17 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5018f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SATVRMID</th>
#       <th class="col_heading level0 col1" >SATMTMID</th>
#       <th class="col_heading level0 col2" >UGDS</th>
#       <th class="col_heading level0 col3" >UGDS_WHITE</th>
#       <th class="col_heading level0 col4" >UGDS_BLACK</th>
#       <th class="col_heading level0 col5" >UGDS_HISP</th>
#       <th class="col_heading level0 col6" >UGDS_ASIAN</th>
#       <th class="col_heading level0 col7" >UGDS_AIAN</th>
#       <th class="col_heading level0 col8" >UGDS_NHPI</th>
#       <th class="col_heading level0 col9" >UGDS_2MOR</th>
#       <th class="col_heading level0 col10" >UGDS_NRA</th>
#       <th class="col_heading level0 col11" >UGDS_UNKN</th>
#       <th class="col_heading level0 col12" >PPTUG_EF</th>
#       <th class="col_heading level0 col13" >PCTPELL</th>
#       <th class="col_heading level0 col14" >PCTFLOAN</th>
#       <th class="col_heading level0 col15" >UG25ABV</th>
#       <th class="col_heading level0 col16" >MD_EARN_WNE_P10</th>
#       <th class="col_heading level0 col17" >GRAD_DEBT_MDN_SUPP</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >INSTNM</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5018f_level0_row0" class="row_heading level0 row0" >California Institute of Technology</th>
#       <td id="T_5018f_row0_col0" class="data row0 col0" >765.000000</td>
#       <td id="T_5018f_row0_col1" class="data row0 col1" >785.000000</td>
#       <td id="T_5018f_row0_col2" class="data row0 col2" >983.000000</td>
#       <td id="T_5018f_row0_col3" class="data row0 col3" >0.278700</td>
#       <td id="T_5018f_row0_col4" class="data row0 col4" >0.015300</td>
#       <td id="T_5018f_row0_col5" class="data row0 col5" >0.122100</td>
#       <td id="T_5018f_row0_col6" class="data row0 col6" >0.438500</td>
#       <td id="T_5018f_row0_col7" class="data row0 col7" >0.001000</td>
#       <td id="T_5018f_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_5018f_row0_col9" class="data row0 col9" >0.057000</td>
#       <td id="T_5018f_row0_col10" class="data row0 col10" >0.087500</td>
#       <td id="T_5018f_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_5018f_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_5018f_row0_col13" class="data row0 col13" >0.112600</td>
#       <td id="T_5018f_row0_col14" class="data row0 col14" >0.230300</td>
#       <td id="T_5018f_row0_col15" class="data row0 col15" >0.008200</td>
#       <td id="T_5018f_row0_col16" class="data row0 col16" >77800.000000</td>
#       <td id="T_5018f_row0_col17" class="data row0 col17" >11812.500000</td>
#     </tr>
#     <tr>
#       <th id="T_5018f_level0_row1" class="row_heading level0 row1" >University of Phoenix-Arizona</th>
#       <td id="T_5018f_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_5018f_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_5018f_row1_col2" class="data row1 col2" >151558.000000</td>
#       <td id="T_5018f_row1_col3" class="data row1 col3" >0.309800</td>
#       <td id="T_5018f_row1_col4" class="data row1 col4" >0.155500</td>
#       <td id="T_5018f_row1_col5" class="data row1 col5" >0.076000</td>
#       <td id="T_5018f_row1_col6" class="data row1 col6" >0.008200</td>
#       <td id="T_5018f_row1_col7" class="data row1 col7" >0.004200</td>
#       <td id="T_5018f_row1_col8" class="data row1 col8" >0.005000</td>
#       <td id="T_5018f_row1_col9" class="data row1 col9" >0.113100</td>
#       <td id="T_5018f_row1_col10" class="data row1 col10" >0.013100</td>
#       <td id="T_5018f_row1_col11" class="data row1 col11" >0.315200</td>
#       <td id="T_5018f_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_5018f_row1_col13" class="data row1 col13" >0.600900</td>
#       <td id="T_5018f_row1_col14" class="data row1 col14" >0.592000</td>
#       <td id="T_5018f_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_5018f_row1_col16" class="data row1 col16" >nan</td>
#       <td id="T_5018f_row1_col17" class="data row1 col17" >33000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5018f_level0_row2" class="row_heading level0 row2" >Mr Leon's School of Hair Design-Moscow</th>
#       <td id="T_5018f_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_5018f_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_5018f_row2_col2" class="data row2 col2" >16.000000</td>
#       <td id="T_5018f_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_5018f_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_5018f_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_5018f_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_5018f_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_5018f_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_5018f_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_5018f_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_5018f_row2_col11" class="data row2 col11" >0.000000</td>
#       <td id="T_5018f_row2_col12" class="data row2 col12" >0.000000</td>
#       <td id="T_5018f_row2_col13" class="data row2 col13" >0.625000</td>
#       <td id="T_5018f_row2_col14" class="data row2 col14" >0.625000</td>
#       <td id="T_5018f_row2_col15" class="data row2 col15" >0.200000</td>
#       <td id="T_5018f_row2_col16" class="data row2 col16" >nan</td>
#       <td id="T_5018f_row2_col17" class="data row2 col17" >15710.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5018f_level0_row3" class="row_heading level0 row3" >Velvatex College of Beauty Culture</th>
#       <td id="T_5018f_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_5018f_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_5018f_row3_col2" class="data row3 col2" >25.000000</td>
#       <td id="T_5018f_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_5018f_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_5018f_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_5018f_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_5018f_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_5018f_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_5018f_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_5018f_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_5018f_row3_col11" class="data row3 col11" >0.000000</td>
#       <td id="T_5018f_row3_col12" class="data row3 col12" >0.200000</td>
#       <td id="T_5018f_row3_col13" class="data row3 col13" >0.769200</td>
#       <td id="T_5018f_row3_col14" class="data row3 col14" >0.000000</td>
#       <td id="T_5018f_row3_col15" class="data row3 col15" >0.520000</td>
#       <td id="T_5018f_row

# %% [markdown]
# ## <u>Replicating idmax with method chaining</u>
# <p>idmax is a challenging method to replicate using only the methods covered in this notebook. This procedure chains together
# the basic methods to find all row index values that contain a maximum column value</p>

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                      ...
# Alabama A & M University                      0.0   4206.0  ...     0.0000
# University of Alabama at Birmingham           0.0  11383.0  ...     0.0368
# Amridge University                            1.0    291.0  ...     0.0000
# University of Alabama in Huntsville           0.0   5451.0  ...     0.0172
# Alabama State University                      0.0   4811.0  ...     0.0098
#
#                                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# Alabama A & M University               0.0059     0.0138    0.0656         1
# University of Alabama at Birmingham    0.0179     0.0100    0.2607         1
# Amridge University                     0.0000     0.2715    0.4536         1
# University of Alabama in Huntsville    0.0332     0.0350    0.2146         1
# Alabama State University               0.0243     0.0137    0.0892         1
#
#                                      PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University              0.7356    0.8284   0.1049
# University of Alabama at Birmingham   0.3460    0.5214   0.2422
# Amridge University                    0.6801    0.7795   0.8540
# University of Alabama in Huntsville   0.3072    0.4596   0.2640
# Alabama State University              0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 26 columns]

# %%
#Getting numeric columns that are of interest
cols = ['MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP']
for col in cols:
    college[col] = pd.to_numeric(college[col], errors = 'coerce')

# %%
college_n = college.select_dtypes(include = [np.number])
college_n.head()
# Out:
#                                      HBCU  MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Alabama A & M University              1.0      0.0        0.0         0
# University of Alabama at Birmingham   0.0      0.0        0.0         0
# Amridge University                    0.0      0.0        0.0         1
# University of Alabama in Huntsville   0.0      0.0        0.0         0
# Alabama State University              1.0      0.0        0.0         0
#
#                                      SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Alabama A & M University                424.0     420.0           0.0
# University of Alabama at Birmingham     570.0     565.0           0.0
# Amridge University                        NaN       NaN           1.0
# University of Alabama in Huntsville     595.0     590.0           0.0
# Alabama State University                425.0     430.0           0.0
#
#                                         UGDS  UGDS_WHITE  UGDS_BLACK  ...  \
# INSTNM                                                                ...
# Alabama A & M University              4206.0      0.0333      0.9353  ...
# University of Alabama at Birmingham  11383.0      0.5922      0.2600  ...
# Amridge University                     291.0      0.2990      0.4192  ...
# University of Alabama in Huntsville   5451.0      0.6988      0.1255  ...
# Alabama State University              4811.0      0.0158      0.9208  ...
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138    0.0656
# University of Alabama at Birmingham     0.0368    0.0179     0.0100    0.2607
# Amridge University                      0.0000    0.0000     0.2715    0.4536
# University of Alabama in Huntsville     0.0172    0.0332     0.0350    0.2146
# Alabama State University                0.0098    0.0243     0.0137    0.0892
#
#                                      CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University                    1   0.7356    0.8284   0.1049
# University of Alabama at Birmingham         1   0.3460    0.5214   0.2422
# Amridge University                          1   0.6801    0.7795   0.8540
# University of Alabama in Huntsville         1   0.3072    0.4596   0.2640
# Alabama State University                    1   0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 24 columns]

# %%
criteria = college_n.nunique() == 2
criteria.head()
# Out:
# HBCU          True
# MENONLY       True
# WOMENONLY     True
# RELAFFIL      True
# SATVRMID     False
# dtype: bool

# %% [markdown]
# f = college_n[criteria]
# f

# %%
binary_cols = college_n.columns[criteria].tolist()
binary_cols
# Out:
# ['HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL', 'DISTANCEONLY', 'CURROPER']

# %%
college_n = college_n.drop(labels = binary_cols, axis = 'columns')

# %%
#Finding the maximum for each column:
college_n.max().head()
# Out:
# SATVRMID         765.0
# SATMTMID         785.0
# UGDS          151558.0
# UGDS_WHITE         1.0
# UGDS_BLACK         1.0
# dtype: float64

# %%
#Test each value with its column max
college_n.eq(college_n.max()).head()
# Out:
#                                      SATVRMID  SATMTMID   UGDS  UGDS_WHITE  \
# INSTNM
# Alabama A & M University                False     False  False       False
# University of Alabama at Birmingham     False     False  False       False
# Amridge University                      False     False  False       False
# University of Alabama in Huntsville     False     False  False       False
# Alabama State University                False     False  False       False
#
#                                      UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                  False      False       False
# University of Alabama at Birmingham       False      False       False
# Amridge University                        False      False       False
# University of Alabama in Huntsville       False      False       False
# Alabama State University                  False      False       False
#
#                                      UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  \
# INSTNM
# Alabama A & M University                 False      False      False
# University of Alabama at Birmingham      False      False      False
# Amridge University                       False      False      False
# University of Alabama in Huntsville      False      False      False
# Alabama State University                 False      False      False
#
#                                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  PCTPELL  \
# INSTNM
# Alabama A & M University                False      False     False    False
# University of Alabama at Birmingham     False      False     False    False
# Amridge University                      False      False     False    False
# University of Alabama in Huntsville     False      False     False    False
# Alabama State University                False      False     False    False
#
#                                      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                False    False            False
# University of Alabama at Birmingham     False    False            False
# Amridge University                      False    False            False
# University of Alabama in Huntsville     False    False            False
# Alabama State University                False    False            False
#
#                                      GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                          False
# University of Alabama at Birmingham               False
# Amridge University                                False
# University of Alabama in Huntsville               False
# Alabama State University                          False

# %%
#Use of the any method to find rows that have at least one True value:
has_row_max = college_n.eq(college_n.max()).any(axis = 'columns')
has_row_max
# Out:
# INSTNM
# Alabama A & M University                                  False
# University of Alabama at Birmingham                       False
# Amridge University                                        False
# University of Alabama in Huntsville                       False
# Alabama State University                                  False
#                                                           ...
# SAE Institute of Technology  San Francisco                False
# Rasmussen College - Overland Park                         False
# National Personal Training Institute of Cleveland         False
# Bay Area Medical Academy - San Jose Satellite Location    False
# Excel Learning Center-San Antonio South                   False
# Length: 7535, dtype: bool

# %%
#There are 18 columns thus 18 True values in has_row_max
#Let us find out how many they are:
has_row_max.sum()
# Out:
# 401

# %% [markdown]
# <p>This was a bit unexpected, but it turns out that there are columns with manyrows that equal the maximum value. This is
# common with many of the percentage columns that have a maximum of 1. idxmax returns the first occurrence of the maximum value.
# Let us back up a bit, remove the any method, and look at the output above. Let us run the cumsum method instead to accumulate
# all the True values. The first and last three rows are shown:</p>

# %%
#cumsum accumulates all True values:
college_n.eq(college_n.max()).cumsum()
# Out:
#                                                     SATVRMID  SATMTMID  UGDS  \
# INSTNM
# Alabama A & M University                                   0         0     0
# University of Alabama at Birmingham                        0         0     0
# Amridge University                                         0         0     0
# University of Alabama in Huntsville                        0         0     0
# Alabama State University                                   0         0     0
# ...                                                      ...       ...   ...
# SAE Institute of Technology  San Francisco                 1         1     1
# Rasmussen College - Overland Park                          1         1     1
# National Personal Training Institute of Cleveland          1         1     1
# Bay Area Medical Academy - San Jose Satellite L...         1         1     1
# Excel Learning Center-San Antonio South                    1         1     1
#
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                     0           0
# University of Alabama at Birmingham                          0           0
# Amridge University                                           0           0
# University of Alabama in Huntsville                          0           0
# Alabama State University                                     0           0
# ...                                                        ...         ...
# SAE Institute of Technology  San Francisco                 109          28
# Rasmussen College - Overland Park                          109          28
# National Personal Training Institute of Cleveland          109          28
# Bay Area Medical Academy - San Jose Satellite L...         109          28
# Excel Learning Center-San Antonio South                    109          28
#
#                                                     UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                                    0           0
# University of Alabama at Birmingham                         0           0
# Amridge University                                          0           0
# University of Alabama in Huntsville                         0           0
# Alabama State University                                    0           0
# ...                                                       ...         ...
# SAE Institute of Technology  San Francisco                136           1
# Rasmussen College - Overland Park                         136           1
# National Personal Training Institute of Cleveland         136           1
# Bay Area Medical Academy - San Jose Satellite L...        136           1
# Excel Learning Center-San Antonio South                   136           1
#
#                                                     UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                                    0          0
# University of Alabama at Birmingham                         0          0
# Amridge University                                          0          0
# University of Alabama in Huntsville                         0          0
# Alabama State University                                    0          0
# ...                                                       ...        ...
# SAE Institute of Technology  San Francisco                  2          1
# Rasmussen College - Overland Park                           2          1
# National Personal Training Institute of Cleveland           2          1
# Bay Area Medical Academy - San Jose Satellite L...          2          1
# Excel Learning Center-San Antonio South                     2          1
#
#                                                     UGDS_2MOR  UGDS_NRA  \
# INSTNM
# Alabama A & M University                                    0         0
# University of Alabama at Birmingham                         0         0
# Amridge University                                          0         0
# University of Alabama in Huntsville                         0         0
# Alabama State University                                    0         0
# ...                                                       ...       ...
# SAE Institute of Technology  San Francisco                  1         1
# Rasmussen College - Overland Park                           1         1
# National Personal Training Institute of Cleveland           1         1
# Bay Area Medical Academy - San Jose Satellite L...          1         1
# Excel Learning Center-San Antonio South                     1         1
#
#                                                     UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Alabama A & M University                                    0         0
# University of Alabama at Birmingham                         0         0
# Amridge University                                          0         0
# University of Alabama in Huntsville                         0         0
# Alabama State University                                    0         0
# ...                                                       ...       ...
# SAE Institute of Technology  San Francisco                  1        44
# Rasmussen College - Overland Park                           1        44
# National Personal Training Institute of Cleveland           1        44
# Bay Area Medical Academy - San Jose Satellite L...          1        44
# Excel Learning Center-San Antonio South                     1        44
#
#                                                     PCTPELL  PCTFLOAN  \
# INSTNM
# Alabama A & M University                                  0         0
# University of Alabama at Birmingham                       0         0
# Amridge University                                        0         0
# University of Alabama in Huntsville                       0         0
# Alabama State University                                  0         0
# ...                                                     ...       ...
# SAE Institute of Technology  San Francisco               66        55
# Rasmussen College - Overland Park                        66        55
# National Personal Training Institute of Cleveland        66        55
# Bay Area Medical Academy - San Jose Satellite L...       66        55
# Excel Learning Center-San Antonio South                  66        55
#
#                                                     UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                  0                0
# University of Alabama at Birmingham                       0                0
# Amridge University                                        0                0
# University of Alabama in Huntsville                       0                0
# Alabama State University                                  0                0
# ...                                                     ...              ...
# SAE Institute of Technology  San Francisco               12                1
# Rasmussen College - Overland Park                        12                1
# National Personal Training Institute of Cleveland        12                1
# Bay Area Medical Academy - San Jose Satellite L...       12                1
# Excel Learning Center-San Antonio South                  12                1
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                             0
# University of Alabama at Birmingham                                  0
# Amridge University                                                   0
# University of Alabama in Huntsville                                  0
# Alabama State University                                             0
# ...                                                                ...
# SAE Institute of Technology  San Francisco                           2
# Rasmussen College - Overland Park                                    2
# National Personal Training Institute of Cleveland                    2
# Bay Area Medical Academy - San Jose Satellite L...                   2
# Excel Learning Center-San Antonio South                              2
#
# [7535 rows x 18 columns]

# %% [markdown]
# <p>Some columns have one unique maximum like SATVRMID and SATMTMID, while others like UGDS_WHITE have many. 109 schools have
# 100% of their undergraduates as white. If we chain the cumsum method one more time, the value 1 would only appear once in each
# column and it would be the first occurrence of the maximum:</p>

# %%
college_n.eq(college_n.max()).cumsum().cumsum()
# Out:
#                                                     SATVRMID  SATMTMID  UGDS  \
# INSTNM
# Alabama A & M University                                   0         0     0
# University of Alabama at Birmingham                        0         0     0
# Amridge University                                         0         0     0
# University of Alabama in Huntsville                        0         0     0
# Alabama State University                                   0         0     0
# ...                                                      ...       ...   ...
# SAE Institute of Technology  San Francisco              7305      7305   415
# Rasmussen College - Overland Park                       7306      7306   416
# National Personal Training Institute of Cleveland       7307      7307   417
# Bay Area Medical Academy - San Jose Satellite L...      7308      7308   418
# Excel Learning Center-San Antonio South                 7309      7309   419
#
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                     0           0
# University of Alabama at Birmingham                          0           0
# Amridge University                                           0           0
# University of Alabama in Huntsville                          0           0
# Alabama State University                                     0           0
# ...                                                        ...         ...
# SAE Institute of Technology  San Francisco              379750       73107
# Rasmussen College - Overland Park                       379859       73135
# National Personal Training Institute of Cleveland       379968       73163
# Bay Area Medical Academy - San Jose Satellite L...      380077       73191
# Excel Learning Center-San Antonio South                 380186       73219
#
#                                                     UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University                                    0           0
# University of Alabama at Birmingham                         0           0
# Amridge University                                          0           0
# University of Alabama in Huntsville                         0           0
# Alabama State University                                    0           0
# ...                                                       ...         ...
# SAE Institute of Technology  San Francisco             341103         983
# Rasmussen College - Overland Park                      341239         984
# National Personal Training Institute of Cleveland      341375         985
# Bay Area Medical Academy - San Jose Satellite L...     341511         986
# Excel Learning Center-San Antonio South                341647         987
#
#                                                     UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                                    0          0
# University of Alabama at Birmingham                         0          0
# Amridge University                                          0          0
# University of Alabama in Huntsville                         0          0
# Alabama State University                                    0          0
# ...                                                       ...        ...
# SAE Institute of Technology  San Francisco              11382       3316
# Rasmussen College - Overland Park                       11384       3317
# National Personal Training Institute of Cleveland       11386       3318
# Bay Area Medical Academy - San Jose Satellite L...      11388       3319
# Excel Learning Center-San Antonio South                 11390       3320
#
#                                                     UGDS_2MOR  UGDS_NRA  \
# INSTNM
# Alabama A & M University                                    0         0
# University of Alabama at Birmingham                         0         0
# Amridge University                                          0         0
# University of Alabama in Huntsville                         0         0
# Alabama State University                                    0         0
# ...                                                       ...       ...
# SAE Institute of Technology  San Francisco               5056      1076
# Rasmussen College - Overland Park                        5057      1077
# National Personal Training Institute of Cleveland        5058      1078
# Bay Area Medical Academy - San Jose Satellite L...       5059      1079
# Excel Learning Center-San Antonio South                  5060      1080
#
#                                                     UGDS_UNKN  PPTUG_EF  \
# INSTNM
# Alabama A & M University                                    0         0
# University of Alabama at Birmingham                         0         0
# Amridge University                                          0         0
# University of Alabama in Huntsville                         0         0
# Alabama State University                                    0         0
# ...                                                       ...       ...
# SAE Institute of Technology  San Francisco               7276    113649
# Rasmussen College - Overland Park                        7277    113693
# National Personal Training Institute of Cleveland        7278    113737
# Bay Area Medical Academy - San Jose Satellite L...       7279    113781
# Excel Learning Center-San Antonio South                  7280    113825
#
#                                                     PCTPELL  PCTFLOAN  \
# INSTNM
# Alabama A & M University                                  0         0
# University of Alabama at Birmingham                       0         0
# Amridge University                                        0         0
# University of Alabama in Huntsville                       0         0
# Alabama State University                                  0         0
# ...                                                     ...       ...
# SAE Institute of Technology  San Francisco           172944    170273
# Rasmussen College - Overland Park                    173010    170328
# National Personal Training Institute of Cleveland    173076    170383
# Bay Area Medical Academy - San Jose Satellite L...   173142    170438
# Excel Learning Center-San Antonio South              173208    170493
#
#                                                     UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Alabama A & M University                                  0                0
# University of Alabama at Birmingham                       0                0
# Amridge University                                        0                0
# University of Alabama in Huntsville                       0                0
# Alabama State University                                  0                0
# ...                                                     ...              ...
# SAE Institute of Technology  San Francisco            36183             3445
# Rasmussen College - Overland Park                     36195             3446
# National Personal Training Institute of Cleveland     36207             3447
# Bay Area Medical Academy - San Jose Satellite L...    36219             3448
# Excel Learning Center-San Antonio South               36231             3449
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                                             0
# University of Alabama at Birmingham                                  0
# Amridge University                                                   0
# University of Alabama in Huntsville                                  0
# Alabama State University                                             0
# ...                                                                ...
# SAE Institute of Technology  San Francisco                       10266
# Rasmussen College - Overland Park                                10268
# National Personal Training Institute of Cleveland                10270
# Bay Area Medical Academy - San Jose Satellite L...               10272
# Excel Learning Center-San Antonio South                          10274
#
# [7535 rows x 18 columns]

# %%
#We can now test the equality of each value against 1 with the eq method and then use the any method to find rows that have at least one True value:
has_row_max2 = college_n.eq(college_n.max()) \
                        .cumsum() \
                        .cumsum() \
                        .eq(1) \
                        .any(axis='columns')

# %%
#Test that has_row_max2 has no more True values than the number of columns:
has_row_max2.sum()
# Out:
# 16

# %%
#We need all the institutions where has_row_max2 is True.
#We can simply use boolean indexing on the Series itself:
idxmax_cols = has_row_max2[has_row_max2].index
idxmax_cols
# Out:
# Index(['Thunderbird School of Global Management',
#        'Southwest University of Visual Arts-Tucson', 'ABC Beauty College Inc',
#        'Velvatex College of Beauty Culture',
#        'California Institute of Technology',
#        'Le Cordon Bleu College of Culinary Arts-San Francisco',
#        'MTI Business College Inc', 'Dongguk University-Los Angeles',
#        'Mr Leon's School of Hair Design-Moscow',
#        'Haskell Indian Nations University', 'LIU Brentwood',
#        'Medical College of Wisconsin', 'Palau Community College',
#        'California University of Management and Sciences',
#        'Cosmopolitan Beauty and Tech School', 'University of Phoenix-Arizona'],
#       dtype='object', name='INSTNM')

# %%
#We can check whether they are the same as the ones found with the idxmax method:
set(college_n.idxmax().unique()) == set(idxmax_cols)
# Out:
# True

# %%
#The whole process can be chained and timed as follows:
# %timeit college_n.eq(college_n.max()) \
                 .cumsum() \
                 .cumsum() \
                 .eq(1) \
                 .any(axis='columns') \
                 [lambda x: x].index
# Out:
# 6.95 ms ± 578 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit college_n.idxmax().values
# Out:
# 3.44 ms ± 410 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## <u>Finding the most common maximum</u>
# <p>We will find the race with the highest undergraduate population for each school. There after, we can find the disribution of
# the result in the entire dataset. This can help us answer questions like <i>What percentage of institutions have the most white
# students than any other race?</i></p>

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  ...  UGDS_2MOR  \
# INSTNM                                                      ...
# Alabama A & M University                      0.0   4206.0  ...     0.0000
# University of Alabama at Birmingham           0.0  11383.0  ...     0.0368
# Amridge University                            1.0    291.0  ...     0.0000
# University of Alabama in Huntsville           0.0   5451.0  ...     0.0172
# Alabama State University                      0.0   4811.0  ...     0.0098
#
#                                      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# Alabama A & M University               0.0059     0.0138    0.0656         1
# University of Alabama at Birmingham    0.0179     0.0100    0.2607         1
# Amridge University                     0.0000     0.2715    0.4536         1
# University of Alabama in Huntsville    0.0332     0.0350    0.2146         1
# Alabama State University               0.0243     0.0137    0.0892         1
#
#                                      PCTPELL  PCTFLOAN  UG25ABV  \
# INSTNM
# Alabama A & M University              0.7356    0.8284   0.1049
# University of Alabama at Birmingham   0.3460    0.5214   0.2422
# Amridge University                    0.6801    0.7795   0.8540
# University of Alabama in Huntsville   0.3072    0.4596   0.2640
# Alabama State University              0.7347    0.7554   0.1270
#
#                                      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM
# Alabama A & M University                     30300.0             33888.0
# University of Alabama at Birmingham          39700.0             21941.5
# Amridge University                           40100.0             23370.0
# University of Alabama in Huntsville          45500.0             24097.0
# Alabama State University                     26600.0             33118.5
#
# [5 rows x 26 columns]

# %%
col_ugds = college.filter(like = ('UGDS_'))
col_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# Alabama A & M University                0.0000    0.0059     0.0138
# University of Alabama at Birmingham     0.0368    0.0179     0.0100
# Amridge University                      0.0000    0.0000     0.2715
# University of Alabama in Huntsville     0.0172    0.0332     0.0350
# Alabama State University                0.0098    0.0243     0.0137

# %%
#Use idxmax to get the column name with the highest race percentage for each row:
highest_percentage_race = col_ugds.idxmax(axis = 'columns')
highest_percentage_race
# Out:
# INSTNM
# Alabama A & M University                                  UGDS_BLACK
# University of Alabama at Birmingham                       UGDS_WHITE
# Amridge University                                        UGDS_BLACK
# University of Alabama in Huntsville                       UGDS_WHITE
# Alabama State University                                  UGDS_BLACK
#                                                              ...
# SAE Institute of Technology  San Francisco                       NaN
# Rasmussen College - Overland Park                                NaN
# National Personal Training Institute of Cleveland                NaN
# Bay Area Medical Academy - San Jose Satellite Location           NaN
# Excel Learning Center-San Antonio South                          NaN
# Length: 7535, dtype: object

# %%
highest_percentage_race.value_counts()
# Out:
# UGDS_WHITE    4608
# UGDS_BLACK    1042
# UGDS_HISP      890
# UGDS_UNKN      161
# UGDS_ASIAN      83
# UGDS_AIAN       42
# UGDS_NRA        28
# UGDS_NHPI       12
# UGDS_2MOR        8
# dtype: int64

# %%
#Use the value_counts method to get the distrubution of maximum occurences:
highest_percentage_race.value_counts(normalize = True)
# Out:
# UGDS_WHITE    0.670352
# UGDS_BLACK    0.151586
# UGDS_HISP     0.129473
# UGDS_UNKN     0.023422
# UGDS_ASIAN    0.012074
# UGDS_AIAN     0.006110
# UGDS_NRA      0.004073
# UGDS_NHPI     0.001746
# UGDS_2MOR     0.001164
# dtype: float64

# %%
highest_percentage_race.value_counts(normalize = True)*100
# Out:
# UGDS_WHITE    67.035205
# UGDS_BLACK    15.158569
# UGDS_HISP     12.947338
# UGDS_UNKN      2.342159
# UGDS_ASIAN     1.207448
# UGDS_AIAN      0.610998
# UGDS_NRA       0.407332
# UGDS_NHPI      0.174571
# UGDS_2MOR      0.116381
# dtype: float64

# %%
highest_percentage_race.value_counts()
# Out:
# UGDS_WHITE    4608
# UGDS_BLACK    1042
# UGDS_HISP      890
# UGDS_UNKN      161
# UGDS_ASIAN      83
# UGDS_AIAN       42
# UGDS_NRA        28
# UGDS_NHPI       12
# UGDS_2MOR        8
# dtype: int64

# %%
#For the schools with more black students than any other race, what is the distribution for the second highest race percentage?
college_black = col_ugds[highest_percentage_race == 'UGDS_BLACK']
college_black.head()
# Out:
#                              UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# INSTNM
# Alabama A & M University         0.0333      0.9353     0.0055      0.0019
# Amridge University               0.2990      0.4192     0.0069      0.0034
# Alabama State University         0.0158      0.9208     0.0121      0.0019
# Concordia College Alabama        0.0280      0.8758     0.0373      0.0093
# South University-Montgomery      0.3046      0.6054     0.0153      0.0153
#
#                              UGDS_AIAN  UGDS_NHPI  UGDS_2MOR  UGDS_NRA  \
# INSTNM
# Alabama A & M University        0.0024     0.0019     0.0000    0.0059
# Amridge University              0.0000     0.0000     0.0000    0.0000
# Alabama State University        0.0010     0.0006     0.0098    0.0243
# Concordia College Alabama       0.0000     0.0000     0.0031    0.0466
# South University-Montgomery     0.0153     0.0096     0.0000    0.0019
#
#                              UGDS_UNKN
# INSTNM
# Alabama A & M University        0.0138
# Amridge University              0.2715
# Alabama State University        0.0137
# Concordia College Alabama       0.0000
# South University-Montgomery     0.0326

# %%
college_black.shape
# Out:
# (1042, 9)

# %%
#college_black2 = college_black.@drop('UGDS_BLACK', axis = 'columns')

# %%
college_black2.idxmax(axis = 'columns').value_counts(normalize = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12076/814450235.py in <module>
# ----> 1 college_black2.idxmax(axis = 'columns').value_counts(normalize = True)
#
# NameError: name 'college_black2' is not defined
