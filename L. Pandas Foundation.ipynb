# %% [markdown]
# # <u>Chapter 1: PANDAS FOUNDATION</u>
# ## <u>Main concepts</u>
# * [Dissecting the anatomy of a DataFrame](#Dissecting-the-anatomy-of-a-DataFrame)
# * [Accessing the main DataFrame components](#Accessing-the-main-DataFrame-components)
# * [Understanding data types](#Understanding-data-types)
# * [Selecting a single column of data as a Series](#Selecting-a-single-column-of-data-as-a-Series)
# * [Calling Series methods](#Calling-Series-methods)
# * [Working with operators on a Series](#Working-with-operators-on-a-Series)
# * [Chaining Series methods together](#Chaining-Series-methods-together)
# * [Making the index meaningful](#Making-the-index-meaningful)
# * [Renaming row and column names](#Renaming-row-and-column-names)
# * [Creating and deleting columns](#Creating-and-deleting-columns)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## <u>Dissecting the anatomy of a DataFrame</u>
# ### <u>Changing options to get a specific output for the notebook</u>

# %%
pd.set_option('max_columns', 20, 'max_rows', 20)

# %%
#Accepts some Linux commands
# %pwd
# Out:
# 'C:\\Users\\User\\Desktop\\PandasCookbook'

# %% [markdown]
# <p>A DataFrame has two axes; <b>horizontal axis(0)</b> and <b>vertical aixs(1)</b><p>

# %%
movie = pd.read_csv('data\\movie.csv')

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#First 10 rows
movie.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %%
movie.tail(10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4906  Color     Shane Carruth                   143.0      77.0
# 4907  Color  Neill Dela Llana                    35.0      80.0
# 4908  Color  Robert Rodriguez                    56.0      81.0
# 4909  Color   Anthony Vallone                     NaN      84.0
# 4910  Color      Edward Burns                    14.0      95.0
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4906                    291.0                     8.0      David Sullivan
# 4907                      0.0                     0.0     Edgar Tancangco
# ...

# %%
movie.shape
# Out:
# (4916, 28)

# %% [markdown]
# ## <u>Accessing the main DataFrame components</u>

# %%
columns = movie.columns
index = movie.index
data = movie.values

# %%
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
#Series
data
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %% [markdown]
# <p>The <b>index object</b> can be used to refer to all objects that can be used for the index or columns. They are all subclasses of <b>pd.Index</b>. Here is the complete list of index objects:</p>
# <ul>
#     <li>CategoricalIndex</li>
#     <li>MultiIndex</li>
#     <li>IntervalIndex</li>
#     <li>Int64Index</li>
#     <li>UInt64Index</li>
#     <li>Float64Index</li>
#     <li>RangeIndex</li>
#     <li>TimedeltaIndex</li>
#     <li>DatetimeIndex</li>
#     <li>PeriodIndex</li>
# </ul>
# <p><b>RangeIndex</b> is an analogous type of Index that is used in the Python's <b>range</b> object. The whole sequence is not loaded into the memory unless it is necessary to do so. This therefore makes it efficient in saving memory</p>
# <p>Whenever possible, the <b>Index</b> objects are implemented using hash tables to allow fast selection and data alignment. They have a similarity to Python's sets for they allow operations such as intersection and union. They are dissimilar for they are ordered with duplicates allowed. Python dictionaries and sets are implemented using hash tables to provide fast functionality. Numpy is the basis/core of the Pandas library that many objects are built upon.</p>

# %%
type(index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# <p>The qualified class name has the following syntax: <b>package name, path of modules, </b> then <b>the name of the type</b>. To get the <b>qualified class name</b> of the object for the variable columns:</p>

# %%
type(columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(data)
# Out:
# numpy.ndarray

# %%
issubclass(pd.RangeIndex, pd.Index)
# Out:
# True

# %% [markdown]
# ## <u>Understanding data types</u>
# <p>Data may be classified into <b>continuous</b>(numeric and infinite) or <b>categorical</b>(discrete and finite). Pandas does not group data into the two formats but uses the following technical metrics:</p>
#
# |Data type|Numpy/Pandas object|Pandas string name|Notes|
# |:--|:--|:----------------------|:------------------------|
# |Boolean|np.bool|bool|Stored as a single byte|
# |Integer|np.int|int|Default of 64 bits. Unsigned integers are also available as np.uint|
# |Float|np.float|float|Default of 64 bits|
# |Complex|np.complex|complex|Rarely seen in data analysis|
# |Object|np.object|O, object|Strings in Python objects eg. Tuples, lists, dictionaries, etc|
# |Datetime|np.datatime64, pd.Timestamp|datetime64|Specific moment in time with nanosecond precision|
# |Timedelta|np.timedelta64, pd.Timedelta|timedelta64|Amount of time from days to nanoseconds|
# |Categorical|pd.categorical|category|Specific to Pandas only. Useful for object columns with relatively few unique values|

# %%
#Getting the data types for each column
movie.dtypes
# Out:
# color                       object
# director_name               object
# num_critic_for_reviews     float64
# duration                   float64
# director_facebook_likes    float64
#                             ...
# title_year                 float64
# actor_2_facebook_likes     float64
# imdb_score                 float64
# aspect_ratio               float64
# movie_facebook_likes         int64
# Length: 28, dtype: object

# %%
datatypes=pd.DataFrame(movie.dtypes)
datatypes
# Out:
#                                0
# color                     object
# director_name             object
# num_critic_for_reviews   float64
# duration                 float64
# director_facebook_likes  float64
# ...                          ...
# title_year               float64
# actor_2_facebook_likes   float64
# imdb_score               float64
# aspect_ratio             float64
# movie_facebook_likes       int64
#
# [28 rows x 1 columns]

# %%
#Counting the number of each data type in a dataset
#28 columns
movie.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %%
movie.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %% [markdown]
# <p>Columns of the object data type may have data in formats such as integers, booleans, strings, etc. It can even have more
# comples Python objects such as lists or dictionaries</p>

# %% [markdown]
# ## <u>Selecting a single column of data as a Series</u>

# %%
#It can be done as follows:
movie['director_name']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
#Alternatively:
movie.director_name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
#Verification that the output is a series:
type(movie.director_name)
# Out:
# pandas.core.series.Series

# %%
#To convert the output to a one-column DataFrame for ease of manipulation
movie['director_name'].to_frame()
# Out:
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 4911        Scott Smith
# 4912                NaN
# 4913   Benjamin Roberds
# 4914        Daniel Hsia
# 4915           Jon Gunn
#
# [4916 rows x 1 columns]

# %% [markdown]
# ## <u>Calling Series methods</u>

# %%
#To check the capabilities of the pd.Series object:
set(dir(pd.Series))
# Out:
# {'T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
#To check the total number of the methods and attributes in pd.Series:
len(set(dir(pd.Series)))
# Out:
# 421

# %%
#To check the total number of methods and attributes in pd.DataFrame:
len(set(dir(pd.DataFrame)))
# Out:
# 432

# %%
len(set(dir(pd.DataFrame)) & set(dir(pd.Series)))
# Out:
# 365

# %%
len(set(dir(pd.DataFrame)) | set(dir(pd.Series)))
# Out:
# 488

# %%
#Putting director_name and actor_1_facebook_likes into variables:
director = movie['director_name']
actor_1_facebook_likes = movie['actor_1_facebook_likes']

# %%
type(director)
# Out:
# pandas.core.series.Series

# %%
#Inspecting the head of each of them:
director.head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
actor_1_facebook_likes.head()
# Out:
# 0     1000.0
# 1    40000.0
# 2    11000.0
# 3    27000.0
# 4      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
f = pd.DataFrame(director.value_counts())
f
# Out:
#                   director_name
# Steven Spielberg             26
# Woody Allen                  22
# Martin Scorsese              20
# Clint Eastwood               20
# Ridley Scott                 16
# ...                         ...
# John Putch                    1
# Luca Guadagnino               1
# Sam Fell                      1
# Dan Fogelman                  1
# Daniel Hsia                   1
#
# [2397 rows x 1 columns]

# %%
#To count the number of occurences of each values:
director.value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        16
#                     ..
# John Putch           1
# Luca Guadagnino      1
# Sam Fell             1
# Dan Fogelman         1
# Daniel Hsia          1
# Name: director_name, Length: 2397, dtype: int64

# %%
directors = director.value_counts().to_frame()

# %%
directors
# Out:
#                   director_name
# Steven Spielberg             26
# Woody Allen                  22
# Martin Scorsese              20
# Clint Eastwood               20
# Ridley Scott                 16
# ...                         ...
# John Putch                    1
# Luca Guadagnino               1
# Sam Fell                      1
# Dan Fogelman                  1
# Daniel Hsia                   1
#
# [2397 rows x 1 columns]

# %%
#It seems as if most of the values have been rounded off to the nearest thousand:
actor_1_facebook_likes.value_counts()
# Out:
# 1000.0     436
# 11000.0    206
# 2000.0     189
# 3000.0     150
# 12000.0    131
#           ...
# 703.0        1
# 208.0        1
# 79.0         1
# 269.0        1
# 291.0        1
# Name: actor_1_facebook_likes, Length: 877, dtype: int64

# %%
actor_1_facebook_likes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64>

# %%
#Counting the number of elements:
director.shape
# Out:
# (4916,)

# %%
director.size
# Out:
# 4916

# %%
len(director)
# Out:
# 4916

# %%
#To get the number of non-missing values:
director.count() #director.notnull.sum()
# Out:
# 4814

# %%
director.notnull().sum()
# Out:
# 4814

# %%
#To get the number of missing values:
director.isnull().sum()
# Out:
# 102

# %%
4814+102
# Out:
# 4916

# %%
#Summary of mathematical functions
actor_1_facebook_likes.min(), actor_1_facebook_likes.max(), \
actor_1_facebook_likes.mean(), actor_1_facebook_likes.median(), \
actor_1_facebook_likes.std(), actor_1_facebook_likes.sum()
# Out:
# (0.0, 640000.0, 6494.488490527602, 982.0, 15106.986883848309, 31881444.0)

# %%
#The above code can be summarized as follows:
actor_1_facebook_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
director.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %%
#This Series had strings thus appears in a different format
director.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %%
#To calculate the exact quantile of numeric data:
actor_1_facebook_likes.quantile(.2)
# Out:
# 510.0

# %%
actor_1_facebook_likes.quantile([.1, .2, .3, .4, .5, .6, .7, .8, .9])
# Out:
# 0.1      240.0
# 0.2      510.0
# 0.3      694.0
# 0.4      854.0
# 0.5      982.0
# 0.6     1000.0
# 0.7     8000.0
# 0.8    13000.0
# 0.9    18000.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
#To know whether a feature has at least one missing values:
director.hasnans
# Out:
# True

# %%
#To get a Series of Booleans equal to the length of the original Series:
director.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
#What is the sum of missing values
director.isnull().sum()
# Out:
# 102

# %%
#To get a Series of Booleans equal to the length of the original Series:
director.notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4911     True
# 4912    False
# 4913     True
# 4914     True
# 4915     True
# Name: director_name, Length: 4916, dtype: bool

# %%
director.notnull().sum()
# Out:
# 4814

# %%
#To fill all missing values with zeros:
actor_1_facebook_likes_filled =  actor_1_facebook_likes.fillna(0)

# %%
actor_1_facebook_likes_filled.count()
# Out:
# 4916

# %%
#To drop missing values:
actor_1_facebook_likes_dropped = actor_1_facebook_likes.dropna()

# %%
actor_1_facebook_likes_dropped.count()
# Out:
# 4909

# %%
#To get a relative frequency of the counts of the distribution:
director.value_counts(normalize = True)
# Out:
# Steven Spielberg    0.005401
# Woody Allen         0.004570
# Martin Scorsese     0.004155
# Clint Eastwood      0.004155
# Ridley Scott        0.003324
#                       ...
# John Putch          0.000208
# Luca Guadagnino     0.000208
# Sam Fell            0.000208
# Dan Fogelman        0.000208
# Daniel Hsia         0.000208
# Name: director_name, Length: 2397, dtype: float64

# %% [markdown]
# ## <u>Working with operators on a Series</u>

# %%
#Operators can work on any data type:
'abcde' + 'fg'
# Out:
# 'abcdefg'

# %%
not (5 <= 9)
# Out:
# False

# %%
7 in [1, 2, 6]
# Out:
# False

# %%
#Not all operators are meant for all objects:
#[1, 2, 3] - 3

# %%
a = set([1, 2, 3])

# %%
#a[0]

# %%
imdb_score = movie['imdb_score']

# %%
imdb_score
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 4911    7.7
# 4912    7.5
# 4913    6.3
# 4914    6.3
# 4915    6.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score + 1
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
#        ...
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score * 2.5
# Out:
# 0       19.75
# 1       17.75
# 2       17.00
# 3       21.25
# 4       17.75
#         ...
# 4911    19.25
# 4912    18.75
# 4913    15.75
# 4914    15.75
# 4915    16.50
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#Floor division
imdb_score // 7
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 4911    1.0
# 4912    1.0
# 4913    0.0
# 4914    0.0
# 4915    0.0
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score > 7
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 4911     True
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: imdb_score, Length: 4916, dtype: bool

# %%
director == 'James Cameron'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
imdb_score.add(1)
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
#        ...
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#Others are add, sub, div, floordiv, mod, pow
imdb_score.mul(2.5)
# Out:
# 0       19.75
# 1       17.75
# 2       17.00
# 3       21.25
# 4       17.75
#         ...
# 4911    19.25
# 4912    18.75
# 4913    15.75
# 4914    15.75
# 4915    16.50
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score.floordiv(7)
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
#        ...
# 4911    1.0
# 4912    1.0
# 4913    0.0
# 4914    0.0
# 4915    0.0
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#Others are: lt, ge, le, eq, ne
imdb_score.gt(7)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 4911     True
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: imdb_score, Length: 4916, dtype: bool

# %%
director.eq('James Cameron')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
director.eq('James Cameron').sum()
# Out:
# 7

# %%
#Special methods:
imdb_score.__mul__(2.5)
# Out:
# 0       19.75
# 1       17.75
# 2       17.00
# 3       21.25
# 4       17.75
#         ...
# 4911    19.25
# 4912    18.75
# 4913    15.75
# 4914    15.75
# 4915    16.50
# Name: imdb_score, Length: 4916, dtype: float64

# %% [markdown]
# ## <u>Chaining Series methods together</u>
# <p>In Python, every variable is an object and all objects have attributes and methods that refer to them to return more objects. This sequential invocation of methods using the dot notation is referred to as <b>method chaining</b>. The backslash(\) sign is used to write the chained code in several lines. A parenthesis can also be used to wrap the whole expression. To improve readability, you can placeeach method directly under the dot above it</p>

# %%
#The head method is commonly appended to the chain to suppress a long output.
#For shorter chains, there is no need to place each method on a different line:
director.value_counts().head(3)
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Name: director_name, dtype: int64

# %%
#A commonly used chain method is this one:
actor_1_facebook_likes.isnull().sum()
# Out:
# 7

# %%
actor_1_facebook_likes.notnull().sum()
# Out:
# 4909

# %%
#All non-missing values should be integers, all missing values should be filled with zeros then be of integer data type:
actor_1_facebook_likes.fillna(0)\
                      .astype(int)\
                      .head()
# Out:
# 0     1000
# 1    40000
# 2    11000
# 3    27000
# 4      131
# Name: actor_1_facebook_likes, dtype: int32

# %%
#We can also take the mean of the Series to get the percentage of values that are missing:
actor_1_facebook_likes.isnull().mean()
# Out:
# 0.0014239218877135883

# %%
#Parenthesis can be used as follows:
(actor_1_facebook_likes.fillna(0)
                 .astype(int)
                 .head())
# Out:
# 0     1000
# 1    40000
# 2    11000
# 3    27000
# 4      131
# Name: actor_1_facebook_likes, dtype: int32

# %% [markdown]
# <p>The method chaining method has its downfalls such as:
# <ul>
# <li>Challenges in debugging</li>
# <li>None of the intermediate outputs is stored in a variable</li>
# </ul>

# %% [markdown]
# ## <u>Making the index meaningful</u>

# %% [markdown]
# <p>he index of a DataFrame provides a label for each of the rows. If no index is explicitly provided upon DataFrame creation,
# then by default, a RangeIndex is created with labels as integers from 0 to n-1, where n is the number of rows.</p>

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#To set the title of each movie as the new index:
movie2 = movie.set_index('movie_title')

# %%
movie2.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
#It can also be set from the time the dataset is being called:
movie3 = pd.read_csv('data/movie.csv', index_col = 'movie_title')

# %%
movie3.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
#To make movie_title to be a column once again to the RangeIndex format:
movie2
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# ...

# %%
movie2.reset_index()
# Out:
#                                      movie_title  color      director_name  \
# 0                                         Avatar  Color      James Cameron
# 1       Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# 2                                        Spectre  Color         Sam Mendes
# 3                          The Dark Knight Rises  Color  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                          ...    ...                ...
# 4911                     Signed Sealed Delivered  Color        Scott Smith
# 4912                               The Following  Color                NaN
# 4913                        A Plague So Pleasant  Color   Benjamin Roberds
# 4914                            Shanghai Calling  Color        Daniel Hsia
# 4915                           My Date with Drew  Color           Jon Gunn
#
#       num_critic_for_reviews  duration  director_facebook_likes  \
# ...

# %% [markdown]
# ## <u>Renaming row and column names</u>

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
#The rename DataFrame method accepts dictionaries that map old values to new values
idx_rename = {'Avatar' : 'Ratava', 'Spectre' : 'Ertceps'}
col_rename = {'director_name' : 'Director Name', 'num_critic_for_reviews' : 'Critical Reviews'}

# %%
movie_renamed = movie.rename(index = idx_rename, columns = col_rename)

# %%
movie_renamed.head()
# Out:
#                                             color      Director Name  \
# movie_title
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# movie_title
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# ...

# %%
#Columns and rows can also be converted to lists then be renamed:
movie = pd.read_csv('data/movie.csv', index_col='movie_title')
index = movie.index
columns = movie.columns

# %%
index_list = index.to_list()

# %%
column_list = columns.to_list()

# %%
index_list
# Out:
# ['Avatar',
#  "Pirates of the Caribbean: At World's End",
#  'Spectre',
#  'The Dark Knight Rises',
#  'Star Wars: Episode VII - The Force Awakens',
#  'John Carter',
#  'Spider-Man 3',
#  'Tangled',
#  'Avengers: Age of Ultron',
#  'Harry Potter and the Half-Blood Prince',
#  'Batman v Superman: Dawn of Justice',
#  'Superman Returns',
#  'Quantum of Solace',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Lone Ranger',
#  'Man of Steel',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Avengers',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Men in Black 3',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Amazing Spider-Man',
#  'Robin Hood',
#  'The Hobbit: The Desolation of Smaug',
#  'The Golden Compass',
#  'King Kong',
#  'Titanic',
#  'Captain America: Civil War',
#  'Battleship',
#  'Jurassic World',
#  'Skyfall',
#  'Spider-Man 2',
#  'Iron Man 3',
#  'Alice in Wonderland',
#  'X-Men: The Last Stand',
#  'Monsters University',
# ...

# %%
column_list
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
#You can now rename the rows and columns individually:
index_list[0] = 'Ratava'
index_list[2] = 'Ertceps'
column_list[1] = 'Director Name'
column_list[2] = 'Critical Reviews'

# %%
#Assign the new list to the initial dataset:
movie.index = index_list
movie.columns = column_list

# %% [markdown]
# ## <u>Creating and deleting columns</u>

# %%
#Creating a column and filling it with zeros. Created columns will go to the end of the dataset:
movie['has_seen'] = 0

# %%
movie.head()
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %%
#Adding up the columns with actor and director facebook likes and assign them to a new column:
movie['actor_director_facebook_likes'] = \
    (movie['actor_1_facebook_likes'] +
    movie['actor_2_facebook_likes'] +
    movie['actor_3_facebook_likes'] +
    movie['director_facebook_likes'])

# %% [markdown]
# <p>This dataset contains missing values. When numeric columns are added to one another as in the preceding step, pandas defaults
# missing values to zero. But, if all values for a particular row are missing, then pandas keeps the total as missing as well</p>

# %%
movie['actor_director_facebook_likes'].isnull().sum()
# Out:
# 122

# %%
movie.actor_director_facebook_likes.fillna(0)
movie.actor_director_facebook_likes.isnull().sum()
# Out:
# 122

# %%
#The above code syntax can be replaced with this one below:
movie['actor_director_facebook_likes'] = \
movie['actor_director_facebook_likes'].fillna(0)

# %%
movie['actor_director_facebook_likes'].isnull().sum()
# Out:
# 0

# %%
movie.head()
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %%
#Check whether all values in the cast_total_facebook_likes are greater than the actor_total_facebook_likes:
movie['is_cast_likes_more'] = movie['cast_total_facebook_likes'] >= movie['actor_director_facebook_likes']

# %%
movie['is_cast_likes_more'].all()
# Out:
# False

# %%
movie['is_cast_likes_more'].notnull().sum()
# Out:
# 4916

# %%
#Calculation of the total percentage of the cast_total_facebook_likes that come from actor_total_facebook_likes:
movie['pct_actor_cast_like'] = \
(movie['actor_director_facebook_likes'] /
movie['cast_total_facebook_likes'])

# %%
movie['pct_actor_cast_like']
# Out:
# Ratava                                        0.577369
# Pirates of the Caribbean: At World's End      0.963040
# Ertceps                                       0.987521
# The Dark Knight Rises                         0.889855
# Star Wars: Episode VII - The Force Awakens    0.000000
#                                                 ...
# Signed Sealed Delivered                       0.625055
# The Following                                 0.000000
# A Plague So Pleasant                               NaN
# Shanghai Calling                              0.902766
# My Date with Drew                             0.865031
# Name: pct_actor_cast_like, Length: 4916, dtype: float64

# %%
#Let us validate that the min and max of this column fall between 0 and 1:
(movie['pct_actor_cast_like'].min(), movie['pct_actor_cast_like'].max())
# Out:
# (0.0, inf)

# %%
#To output the column as a Series and set the index to the movie title so that we can properly identify each value:
movie.set_index('Director Name')['pct_actor_cast_like'].head()
# Out:
# Director Name
# James Cameron        0.577369
# Gore Verbinski       0.963040
# Sam Mendes           0.987521
# Christopher Nolan    0.889855
# Doug Walker          0.000000
# Name: pct_actor_cast_like, dtype: float64

# %%
#Inserting a column at a specific index:
#Getting the index of the column that comes before the column you want to add:
columns.get_loc('gross')
# Out:
# 8

# %%
#The column to be added will be the profit_index column(The difference between the budget and the gross):
#The position where the new column will be added:
profit_index = columns.get_loc('gross') + 1
profit_index
# Out:
# 9

# %%
type(profit_index)
# Out:
# int

# %%
movie.insert(loc = 9, column = 'profits', value = movie['gross'] - movie['budget'])
movie.head()
# Out:
#                                             color      Director Name  \
# Ratava                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Ertceps                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             Critical Reviews  duration  \
# Ratava                                                 723.0     178.0
# Pirates of the Caribbean: At World's End               302.0     169.0
# Ertceps                                                602.0     148.0
# The Dark Knight Rises                                  813.0     164.0
# Star Wars: Episode VII - The Force Awakens               NaN       NaN
#
#                                             director_facebook_likes  \
# ...

# %%
movie.columns
# Out:
# Index(['color', 'Director Name', 'Critical Reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'profits', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes', 'has_seen',
#        'actor_director_facebook_likes', 'is_cast_likes_more',
#        'pct_actor_cast_like'],
#       dtype='object')

# %%
#Deleting columns can be done as follows:
del movie['actor_director_facebook_likes']

# %% [markdown]
# # <p>THE END OF PART ONE</p>

# %%
import pandas as pd

# %%
data = {'animal': ['panda', 'koala'],
        'favorite_food': ['bamboo', 'eucalyptus'],
        'cuteness_level': [100, 100]}
pd.DataFrame.from_dict(data, orient = 'index', columns = ['first_animal', 'second_animal'])
# Out:
#                first_animal second_animal
# animal                panda         koala
# favorite_food        bamboo    eucalyptus
# cuteness_level          100           100
